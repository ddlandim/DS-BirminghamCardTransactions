# %% [markdown]
# # Import libraries

# %%
import os
import pandas as pd
from pandas.plotting import autocorrelation_plot
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import OneClassSVM, SVR
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima.model import ARIMA

# %% [markdown]
# # Merging Spreatsheets by year

# %%
cwd = os.chdir("/Dataset")
files = os.listdir(cwd)

df_2014 = pd.DataFrame()
df_2015 = pd.DataFrame()
df_2016 = pd.DataFrame()
df_2017 = pd.DataFrame()
df_2018 = pd.DataFrame()

# Merging the files for the year: 2014
for f in files:
    if f.endswith(".xls") and "2014" in f:
        df_2014 = df_2014.append(pd.read_excel(f, index_col = 'TRANS DATE', parse_dates = True))
        
# Merging the files for the year: 2015
for f in files:
    if f.endswith(".xls") and "2015" in f:
        df_2015 = df_2015.append(pd.read_excel(f, index_col = 'TRANS DATE', parse_dates = True))

# Merging the files for the year: 2016
for f in files:
    if f.endswith(".xls") and "2016" in f:
        df_2016 = df_2016.append(pd.read_excel(f, index_col = 'TRANS DATE', parse_dates = True))
        
# Merging the files for the year: 2017
for f in files:
    if f.endswith(".xls") and "2017" in f:
        df_2017 = df_2017.append(pd.read_excel(f, index_col = 'TRANS DATE', parse_dates = True))
        
# Merging the files for the year: 2018
for f in files:
    if f.endswith(".xls") and "2018" in f:
        df_2018 = df_2018.append(pd.read_excel(f, index_col = 'TRANS DATE', parse_dates = True))

# %% [markdown]
# # Profiling / clustering
# ## Based on people's transactions

# %%
df_2016 = df_2016.drop('Directorates',axis=1)
df_2016 = df_2016.dropna()
df_2016 = df_2016.sort_values(by = 'TRANS DATE')
plt.figure(figsize=(30,20))
plt.plot(df['ORIGINAL GROSS AMT'])
plt.xlabel('Dates')
plt.ylabel('ORIGINAL GROSS AMT')
# Out:
# Text(0, 0.5, 'ORIGINAL GROSS AMT')

# %% [markdown]
# # Preprocessing

# %%
# # Dropping rows that contain NULL values from all DataFrames
df_2014 = df_2014.dropna()
df_2015 = df_2015.dropna()
df_2016 = df_2016.drop('Directorates',axis=1)
df_2016 = df_2016.dropna()
df_2017 = df_2017.dropna()
df_2018 = df_2018.dropna()

# # Standardizing the ORIGINAL GROSS AMT variable
df_2014_orig_gross_amt= pd.DataFrame(df_2014['ORIGINAL GROSS AMT'].values.reshape(-1, 1))
df_2015_orig_gross_amt= pd.DataFrame(df_2015['ORIGINAL GROSS AMT'].values.reshape(-1, 1))
df_2016_orig_gross_amt= pd.DataFrame(df_2016['ORIGINAL GROSS AMT'].values.reshape(-1, 1))
df_2017_orig_gross_amt= pd.DataFrame(df_2017['ORIGINAL GROSS AMT'].values.reshape(-1, 1))
df_2018_orig_gross_amt= pd.DataFrame(df_2018['ORIGINAL GROSS AMT'].values.reshape(-1, 1))

df_2014['ORIGINAL GROSS AMT'] = StandardScaler().fit_transform(df_2014_orig_gross_amt)
df_2015['ORIGINAL GROSS AMT'] = StandardScaler().fit_transform(df_2015_orig_gross_amt)
df_2016['ORIGINAL GROSS AMT'] = StandardScaler().fit_transform(df_2016_orig_gross_amt)
df_2017['ORIGINAL GROSS AMT'] = StandardScaler().fit_transform(df_2017_orig_gross_amt)
df_2018['ORIGINAL GROSS AMT'] = StandardScaler().fit_transform(df_2018_orig_gross_amt)

# # Standardizing the BILLING GROSS AMT variable 

df_2017['BILLING GROSS AMT'] = StandardScaler().fit_transform(df_2017['BILLING GROSS AMT'].values.reshape(-1, 1))
df_2018['BILLING GROSS AMT'] = StandardScaler().fit_transform(df_2018['BILLING GROSS AMT'].values.reshape(-1, 1))

# # Standardizing the TRANS TAX AMT variable
df_2017['TRANS TAX AMT'] = StandardScaler().fit_transform(df_2017['TRANS TAX AMT'].values.reshape(-1, 1))

# # Sorting values by date
df_2014 = df_2014.sort_values(by = 'TRANS DATE')
df_2015 = df_2015.sort_values(by = 'TRANS DATE')
df_2016 = df_2016.sort_values(by = 'TRANS DATE')
df_2017 = df_2017.sort_values(by = 'TRANS DATE')
df_2018 = df_2018.sort_values(by = 'TRANS DATE')

# %%
df = df_2016
df.head()
# Out:
#            TRANS VAT DESC  ORIGINAL GROSS AMT       MERCHANT NAME  \
# TRANS DATE
# 2015-06-25             VR           -0.099683  the consortium/wms
# 2015-09-18             VZ           -0.113460       currys online
# 2015-10-12             VR           -0.241841       currys online
# 2015-11-04             VZ           -0.072931  paypal suziesvarie
# 2015-11-14             VR           -0.192347   credit adjustment
#
#                  CARD NUMBER TRANS CAC CODE 1      TRANS CAC DESC 1  \
# TRANS DATE
# 2015-06-25  ************6158             L080        Mat'l Raw/Drct
# 2015-09-18  ************4193             J310    Other Fix&Fittings
# 2015-10-12  ************0381             P150  Aftercare Assistance
# 2015-11-04  ************7587             K020          Vehicle Fuel
# 2015-11-14  ************0381             P150  Aftercare Assistance
#
#            TRANS CAC CODE 2             TRANS CAC DESC 2 TRANS CAC CODE 3  \
# TRANS DATE
# 2015-06-25            REABR            Bournville Junior              A00
# 2015-09-18            REAMK        St Laurence CE Infant              A00
# 2015-10-12            RV00G  16+ Accommodation & Support              A00
# 2015-11-04            REAFA    Highfield Junior & Infant              A00
# 2015-11-14            RV00G  16+ Accommodation & Support              A00
#
#               Directorate
# TRANS DATE
# 2015-06-25  CYP&F SCHOOLS
# 2015-09-18  CYP&F SCHOOLS
# 2015-10-12          CYP&F
# 2015-11-04  CYP&F SCHOOLS
# 2015-11-14          CYP&F

# %% [markdown]
# # Exploratory analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 43973 entries, 2015-06-25 to 2017-01-02
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   TRANS VAT DESC      43973 non-null  object
#  1   ORIGINAL GROSS AMT  43973 non-null  float64
#  2   MERCHANT NAME       43973 non-null  object
#  3   CARD NUMBER         43973 non-null  object
#  4   TRANS CAC CODE 1    43973 non-null  object
#  5   TRANS CAC DESC 1    43973 non-null  object
#  6   TRANS CAC CODE 2    43973 non-null  object
#  7   TRANS CAC DESC 2    43973 non-null  object
#  8   TRANS CAC CODE 3    43973 non-null  object
#  9   Directorate         43973 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 3.7+ MB

# %%
# Analyse the original gross amt variable;

df['ORIGINAL GROSS AMT'].describe()
# Out:
# count    4.397300e+04
# mean     3.806458e-17
# std      1.000011e+00
# min     -2.089971e+00
# 25%     -9.050942e-02
# 50%     -7.204117e-02
# 75%     -3.994587e-02
# max      6.367468e+01
# Name: ORIGINAL GROSS AMT, dtype: float64

# %%
df['TRANS VAT DESC'].value_counts()
# Out:
# VR    22391
# VZ    21454
# VE       73
# VS       38
# VL       16
# VT        1
# Name: TRANS VAT DESC, dtype: int64

# %%
df['MERCHANT NAME'].value_counts()
# Out:
# amazon uk marketplace        5837
# amazon uk retail             2182
# travelodge website           1270
# asda home shopping            858
# amazon uk retail amazon.c     583
#                              ...
# cambabest t/c 2                 1
# paypal visualstres              1
# secure safe ltd                 1
# www.jfilters.com                1
# www.tes.co.uk                   1
# Name: MERCHANT NAME, Length: 5884, dtype: int64

# %%
df['TRANS CAC CODE 1'].value_counts()
# Out:
# L100    9303
# K020    5473
# L220    4685
# MC70    2848
# L030    2071
#         ...
# M600       1
# N040       1
# N050       1
# L800       1
# L250       1
# Name: TRANS CAC CODE 1, Length: 110, dtype: int64

# %%
df['TRANS CAC DESC 1'].value_counts()
# Out:
# Equip Operational       9303
# Vehicle Fuel            5473
# Purchases Food          4685
# Supplies & Sev Mic      2848
# Books                   2071
#                         ...
# HRM CO Building            1
# Phon Centrx Netwk          1
# HEALTH AUTHORITIES         1
# AMO - Lighting             1
# Insurance NonPremise       1
# Name: TRANS CAC DESC 1, Length: 110, dtype: int64

# %%
df['TRANS CAC CODE 2'].value_counts()
# Out:
# RUF0F    3135
# REAAB    1180
# RJADC     956
# RLBMC     839
# RV014     767
#          ...
# RV0L0       1
# RV0L6       1
# RUBNJ       1
# RHBN1       1
# REH93       1
# Name: TRANS CAC CODE 2, Length: 854, dtype: int64

# %%
df['TRANS CAC DESC 2'].value_counts()
# Out:
# Illegal Money Lending T Stds Comm Inv.    3135
# The City of Birmingham School             1180
# Homeless Private Sector Accom              956
# Technical Unit                             839
# Camborne House HLDC                        767
#                                           ...
# Civil Litigation and PL Team                 1
# Sheldon Library                              1
# Housing Needs Furnished Accom                1
# Ladywood Income                              1
# Kings Norton Boys  (Exgm)                    1
# Name: TRANS CAC DESC 2, Length: 849, dtype: int64

# %%
df['TRANS CAC CODE 3'].value_counts()
# Out:
# A00    43542
# A5F      390
# A46       35
# A9Y        5
# A8F        1
# Name: TRANS CAC CODE 3, dtype: int64

# %%
df['Directorate'].value_counts()
# Out:
# CYP&F SCHOOLS           21338
# Local Services           9021
# CYP&F                    6131
# Adult & Communities      3302
# Corporate Resources      2947
# DEVELOPMENT               791
# CYP&F Schools             190
# CYP&F                      96
# CYP&F                      63
# CYO&F                      49
# Adults                     16
# Local services             12
# Adults & Comms              9
# Adults & Communities        8
# Name: Directorate, dtype: int64

# %%
plt.figure(figsize=(30,20))
plt.plot(df['ORIGINAL GROSS AMT'])
plt.xlabel('Dates')
plt.ylabel('ORIGINAL GROSS AMT')
# Out:
# Text(0, 0.5, 'ORIGINAL GROSS AMT')

# %%
### Here we will do clustering using the KMeans algorithms
# Scaling the frequency of transactions by means amount of transactions
card_tr = card_data.values

# First we need to determine the optimal number of clusters
cluster_range = range(1,16)
cluster_error = []

for num in cluster_range:
    model = KMeans(num)
    model.fit(card_tr)
    cluster_error.append(model.inertia_)

df_clust = pd.DataFrame({'cluster_number':cluster_range,'cluster_error':cluster_error})


plt.figure(figsize=(20,10))
plt.xticks(range(1,16))
plt.plot(df_clust.cluster_number,df_clust.cluster_error, marker="o")
plt.xlabel("Number of cluster")
plt.ylabel("Cluster inertia")
# Out:
# Text(0, 0.5, 'Cluster inertia')

# %%
# The elbow graph showed us that 4 clusters is the optimal number
# so we'll start implementing the code

kmeans_model = KMeans(n_clusters=4)
kmeans_model.fit(card_tr)
kmeans_predict = kmeans_model.predict(card_tr)
kmeans_centroids = kmeans_model.cluster_centers_

plt.figure(figsize=(20,10))
plt.scatter(card_tr[:,1],card_tr[:,0], c=kmeans_predict)
plt.scatter(kmeans_centroids[:,0], kmeans_centroids[:,1], c='black', s=150, alpha=0.5)
plt.xlabel('Frequencies of transactions made by each person')
plt.ylabel('The average transactions made by each person')
# Out:
# Text(0, 0.5, 'The average transactions made by each person')

# %% [markdown]
# ## Based on merchants

# %%
### Converting categorical variables about cards into numerical ones

# Frequency of transactions made by each unique card
card_vc = df['CARD NUMBER'].value_counts()

# Transforming it into a DataFrame
card_vc = pd.DataFrame(card_vc)
card_vc = card_vc.reset_index()
card_vc.columns = ['unique_card','counts']

sum_tr = 0
card_trans = pd.DataFrame()
j = 0

# Average amount of transactions by each unique card
for m in card_vc['unique_card']:
    for i in range(len(df['CARD NUMBER'])):
        if df['CARD NUMBER'][i] == m:
            sum_tr += df['ORIGINAL GROSS AMT'][i]
    card_trans = card_trans.append([(sum_tr/card_vc['counts'][j])])
    j += 1

# Assembling previous data
card_data = pd.DataFrame()
card_data['card_name'] = card_vc['unique_card']
card_data['trans_avg'] = card_trans.values.reshape(-1,1)
card_data['frequency'] = card_vc['counts']

card_data = card_data.set_index(card_data.card_name)
card_data = card_data.drop(['card_name'], axis = 1)

card_data

# %%
# Frequency of transactions made by each unique card
card_vc = df['CARD NUMBER'].value_counts()

# Transforming it into a DataFrame
card_vc = pd.DataFrame(card_vc)
card_vc = card_vc.reset_index()
card_vc.columns = ['unique_card','counts']

sum_tr = 0
card_trans = pd.DataFrame()
j = 0

# Average amount of transactions by each unique card
for m in card_vc['unique_card']:
    for i in range(len(df['CARD NUMBER'])):
        if df['CARD NUMBER'][i] == m:
            sum_tr += df['ORIGINAL GROSS AMT'][i]
    card_trans = card_trans.append([(sum_tr/card_vc['counts'][j])])
    j += 1

# Assembling previous data
card_data = pd.DataFrame()
card_data['card_name'] = card_vc['unique_card']
card_data['trans_avg'] = card_trans.values.reshape(-1,1)
card_data['frequency'] = card_vc['counts']

card_data = card_data.set_index(card_data.card_name)
card_data = card_data.drop(['card_name'], axis = 1)

card_data

# %%
# Frequency of transactions made in favor of ech unique merchant
merchant_vc = df['MERCHANT NAME'].value_counts()

# Transforming it into a DataFrame
merchant = pd.DataFrame(merchant_vc)
merchant = merchant.reset_index()
merchant.columns = ['unique_merchant','counts']

sum_tr = 0
merchant_trans = pd.DataFrame()
j = 0

# Average amount of transactions for each unique merchant
for m in merchant['unique_merchant']:
    for i in range(len(df['MERCHANT NAME'])):
        if df['MERCHANT NAME'][i] == m:
            sum_tr += df['ORIGINAL GROSS AMT'][i]
    merchant_trans = merchant_trans.append([(sum_tr/merchant['counts'][j])])
    j += 1

# Assembling previous data
merchant_data = pd.DataFrame()
merchant_data['merchant_name'] = merchant['unique_merchant']
merchant_data['trans_avg'] = merchant_trans.values.reshape(-1,1)
merchant_data['frequency'] = merchant['counts']

merchant_data = merchant_data.set_index(merchant_data.merchant_name)
merchant_data = merchant_data.drop(['merchant_name'], axis = 1)

merchant_data
# Out:
#                               trans_avg  frequency
# merchant_name
# amazon uk marketplace     -7.646016e-02       5837
# amazon uk retail          -2.717117e-01       2182
# travelodge website        -2.275435e-01       1270
# asda home shopping        -3.933832e-01        858
# amazon uk retail amazon.c -6.490717e-01        583
# ...                                 ...        ...
# cambabest t/c 2           -1.353211e-01          1
# paypal visualstres        -2.283408e-01          1
# secure safe ltd            8.744175e-03          1
# www.jfilters.com           9.195102e-02          1
# www.tes.co.uk             -3.866102e-12          1
#
# [5884 rows x 2 columns]

# %%
plt.figure(figsize=(30,20))
plt.plot(merchant_data.frequency,merchant_data.trans_avg)
plt.xlabel("Frequency of transaction made to a merchant")
plt.ylabel("Average transactions")
# Out:
# Text(0, 0.5, 'Average transactions')

# %%
# The average number of merchants that receive negative average transactions
negative = 0
for i in range(len(merchant_data)):
    if merchant_data.trans_avg[i]<0:
        negative += 1
        
negativ_avg = negative/len(merchant_data)

negativ_avg
# Out:
# 0.13494221617946975

# %%
### Here we will do clustering using the KMeans algorithms
# Scaling the frequency of transactions by means amount of transactions
merchant_tr = merchant_data.values

# First we need to determine the optimal number of clusters
cluster_range = range(1,16)
cluster_error = []

for num in cluster_range:
    model = KMeans(num)
    model.fit(merchant_tr)
    cluster_error.append(model.inertia_)

df_clust = pd.DataFrame({'cluster_number':cluster_range,'cluster_error':cluster_error})


plt.figure(figsize=(20,10))
plt.xticks(range(1,16))
plt.plot(df_clust.cluster_number,df_clust.cluster_error, marker="o")
plt.xlabel("Number of cluster")
plt.ylabel("Cluster inertia")
# Out:
# Text(0, 0.5, 'Cluster inertia')

# %%
# The elbow graph showed us that 4 clusters is the optimal number
# so we'll start implementing the code

kmeans_model = KMeans(n_clusters=4)
kmeans_model.fit(merchant_tr)
kmeans_predict = kmeans_model.predict(merchant_tr)
kmeans_centroids = kmeans_model.cluster_centers_

plt.figure(figsize=(20,10))
plt.scatter(merchant_tr[:,1],merchant_tr[:,0], c=kmeans_predict)
plt.scatter(kmeans_centroids[:,0], kmeans_centroids[:,1], c='black', s=150, alpha=0.5)
plt.xlabel('Frequencies of transactions made by each person')
plt.ylabel('The average transaction made by each person')
# Out:
# Text(0, 0.5, 'The average transaction made by each person')

# %% [markdown]
# ## One-Class SVM

# %%
# Splitting the ORIGINAL GROSS AMOUNT time series data into training and testing datasets (70%+30%)

train_set = df.iloc[0:int(len(df)*0.7),1]
test_set = df.iloc[int(len(df)*0.7)+1:len(df),1]

# %%
# Training the One-Class SVM model 

ocsvm_model = OneClassSVM(gamma ="auto",nu=0.0025).fit(df['ORIGINAL GROSS AMT'].values.reshape(-1,1))
ocsvm_model.predict(df['ORIGINAL GROSS AMT'].values.reshape(-1,1))
ocsvm_decision_func = ocsvm_model.decision_function(df['ORIGINAL GROSS AMT'].values.reshape(-1,1))
ocsvm_score = ocsvm_model.score_samples(df['ORIGINAL GROSS AMT'].values.reshape(-1,1))

df['INT_TIME'] = df.index.astype(np.int64)
df['ocsvm_decis_func'] = ocsvm_decision_func
anomaly = df.loc[df['ocsvm_decis_func']<0, ['INT_TIME','ORIGINAL GROSS AMT']]
normal = df.loc[df['ocsvm_decis_func']>=0, ['INT_TIME','ORIGINAL GROSS AMT']]

fig, ax = plt.subplots(figsize=(10,15))
ax.plot(df['INT_TIME'],df['ORIGINAL GROSS AMT'], color='blue',label='Normal')
ax.scatter(anomaly['INT_TIME'],anomaly['ORIGINAL GROSS AMT'], color='red', label='Anomaly')

plt.xlabel('Date')
plt.ylabel('ORIGINAL GROSS AMT')
plt.legend('Anomaly detection using OCSVM')
plt.show()

# %%
anomaly_fraction = len(anomaly)/len(df['ORIGINAL GROSS AMT'])
anomaly_fraction
# Out:
# 0.00543515338957997

# %% [markdown]
# # Forecasting future transactional behavior

# %%
# splitting training set and test test ona 70%:30% basis from the normal dataset extracted from oncsvm anomaly detection
normal_original_gross_amt = normal['ORIGINAL GROSS AMT']

train_set = normal.iloc[0:int(len(normal)*0.7),1]
train_set.index = pd.DatetimeIndex(train_set.index).to_period('D')
test_set = normal.iloc[int(len(normal)*0.7)+1:len(normal),1]
test_set.index = pd.DatetimeIndex(test_set.index).to_period('D')

# %%
series = normal['ORIGINAL GROSS AMT']

X = series.values
window = 1
history = [X[i] for i in range(window)]
test = [X[i] for i in range(window, len(X))]
predictions = list()
# walk forward over time steps in test
for t in range(len(test)):
    length = len(history)
    yhat = np.mean([history[i] for i in range(length-window,length)])
    obs = test[t]
    predictions.append(yhat)
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot
plt.plot(test)
plt.plot(predictions, color='red')
plt.show()
# zoom plot
plt.plot(test[0:100])
plt.plot(predictions[0:100], color='red')
plt.show()
# Out:
# predicted=-0.099683, expected=-0.113460
# predicted=-0.113460, expected=-0.241841
# predicted=-0.241841, expected=-0.072931
# predicted=-0.072931, expected=-0.192347
# predicted=-0.192347, expected=-0.402741
# predicted=-0.402741, expected=-0.110986
# predicted=-0.110986, expected=-0.086579
# predicted=-0.086579, expected=-0.106138
# predicted=-0.106138, expected=-0.111158
# predicted=-0.111158, expected=-0.111158
# predicted=-0.111158, expected=-0.005900
# predicted=-0.005900, expected=0.013006
# predicted=0.013006, expected=-0.070427
# predicted=-0.070427, expected=-0.094705
# predicted=-0.094705, expected=0.049921
# predicted=0.049921, expected=-0.080648
# predicted=-0.080648, expected=-0.090294
# predicted=-0.090294, expected=0.018973
# predicted=0.018973, expected=-0.094727
# predicted=-0.094727, expected=-0.063973
# predicted=-0.063973, expected=-0.064675
# predicted=-0.064675, expected=-0.095530
# predicted=-0.095530, expected=-0.093428
# predicted=-0.093428, expected=-0.094856
# predicted=-0.094856, expected=-0.091155
# predicted=-0.091155, expected=-0.106281
# predicted=-0.106281, expected=-0.088272
# predicted=-0.088272, expected=-0.055495
# predicted=-0.055495, expected=-0.083402
# predicted=-0.083402, expected=0.080187
# predicted=0.080187, expected=-0.091951
# predicted=-0.091951, expected=-0.084413
# predicted=-0.084413, expected=0.042175
# predicted=0.042175, expected=-0.079887
# predicted=-0.079887, expected=-0.064804
# predicted=-0.064804, expected=-0.089864
# predicted=-0.089864, expected=-0.093665
# predicted=-0.093665, expected=-0.090954
# predicted=-0.090954, expected=-0.076165
# predicted=-0.076165, expected=-0.085869
# predicted=-0.085869, expected=-0.077026
# predicted=-0.077026, expected=-0.095530
# predicted=-0.095530, expected=-0.090481
# predicted=-0.090481, expected=-0.098399
# predicted=-0.098399, expected=-0.028349
# predicted=-0.028349, expected=-0.064553
# predicted=-0.064553, expected=-0.091944
# predicted=-0.091944, expected=-0.094813
# predicted=-0.094813, expected=-0.075878
# predicted=-0.075878, expected=-0.061419
# predicted=-0.061419, expected=-0.097187
# predicted=-0.097187, expected=-0.092747
# predicted=-0.092747, expected=-0.069710
# predicted=-0.069710, expected=-0.052705
# predicted=-0.052705, expected=-0.082627
# predicted=-0.082627, expected=-0.061821
# predicted=-0.061821, expected=-0.096964
# predicted=-0.096964, expected=-0.056370
# predicted=-0.056370, expected=-0.098191
# predicted=-0.098191, expected=-0.091944
# predicted=-0.091944, expected=-0.030278
# predicted=-0.030278, expected=-0.038153
# predicted=-0.038153, expected=-0.092883
# predicted=-0.092883, expected=-0.061498
# predicted=-0.061498, expected=-0.060071
# predicted=-0.060071, expected=-0.061154
# predicted=-0.061154, expected=-0.077600
# predicted=-0.077600, expected=-0.011408
# predicted=-0.011408, expected=-0.082979
# predicted=-0.082979, expected=0.048400
# predicted=0.048400, expected=-0.091399
# predicted=-0.091399, expected=-0.080849
# predicted=-0.080849, expected=-0.091944
# predicted=-0.091944, expected=-0.094949
# predicted=-0.094949, expected=-0.063994
# predicted=-0.063994, expected=0.187963
# predicted=0.187963, expected=0.187963
# predicted=0.187963, expected=0.031632
# predicted=0.031632, expected=-0.060932
# predicted=-0.060932, expected=-0.062538
# predicted=-0.062538, expected=-0.039300
# predicted=-0.039300, expected=-0.062897
# predicted=-0.062897, expected=0.234819
# predicted=0.234819, expected=-0.048194
# predicted=-0.048194, expected=-0.046946
# predicted=-0.046946, expected=-0.046623
# predicted=-0.046623, expected=-0.067530
# predicted=-0.067530, expected=-0.053143
# predicted=-0.053143, expected=-0.068283
# predicted=-0.068283, expected=-0.056800
# predicted=-0.056800, expected=-0.082885
# predicted=-0.082885, expected=0.000577
# predicted=0.000577, expected=-0.091944
# predicted=-0.091944, expected=-0.097201
# predicted=-0.097201, expected=-0.086931
# predicted=-0.086931, expected=0.056562
# predicted=0.056562, expected=0.051284
# predicted=0.051284, expected=-0.089807
# predicted=-0.089807, expected=-0.077528
# predicted=-0.077528, expected=-0.097545
# predicted=-0.097545, expected=0.220044
# predicted=0.220044, expected=0.040741
# predicted=0.040741, expected=-0.066662
# predicted=-0.066662, expected=-0.068053
# predicted=-0.068053, expected=-0.046752
# predicted=-0.046752, expected=-0.063255
# predicted=-0.063255, expected=-0.076703
# predicted=-0.076703, expected=-0.046042
# predicted=-0.046042, expected=-0.096749
# predicted=-0.096749, expected=-0.066017
# predicted=-0.066017, expected=-0.096634
# predicted=-0.096634, expected=-0.047534
# predicted=-0.047534, expected=-0.001274
# predicted=-0.001274, expected=-0.087870
# predicted=-0.087870, expected=-0.052705
# predicted=-0.052705, expected=0.389235
# predicted=0.389235, expected=-0.096964
# predicted=-0.096964, expected=0.115331
# predicted=0.115331, expected=-0.071073
# predicted=-0.071073, expected=-0.095494
# predicted=-0.095494, expected=-0.027395
# predicted=-0.027395, expected=-0.097689
# predicted=-0.097689, expected=-0.095143
# predicted=-0.095143, expected=0.164460
# predicted=0.164460, expected=-0.049026
# predicted=-0.049026, expected=-0.077600
# predicted=-0.077600, expected=-0.093385
# predicted=-0.093385, expected=0.068712
# predicted=0.068712, expected=-0.088229
# predicted=-0.088229, expected=-0.038942
# predicted=-0.038942, expected=-0.081932
# predicted=-0.081932, expected=-0.690494
# predicted=-0.690494, expected=-0.067308
# predicted=-0.067308, expected=-0.067444
# predicted=-0.067444, expected=0.009183
# predicted=0.009183, expected=-0.039394
# predicted=-0.039394, expected=-0.065981
# predicted=-0.065981, expected=-0.088967
# predicted=-0.088967, expected=-0.088967
# predicted=-0.088967, expected=0.011313
# predicted=0.011313, expected=0.009183
# predicted=0.009183, expected=0.009183
# predicted=0.009183, expected=0.228794
# predicted=0.228794, expected=-0.155776
# predicted=-0.155776, expected=-0.094813
# predicted=-0.094813, expected=-0.096950
# predicted=-0.096950, expected=-0.074014
# predicted=-0.074014, expected=-0.063255
# predicted=-0.063255, expected=-0.096756
# predicted=-0.096756, expected=-0.076352
# predicted=-0.076352, expected=-0.096247
# predicted=-0.096247, expected=-0.052504
# predicted=-0.052504, expected=-0.091607
# predicted=-0.091607, expected=-0.026857
# predicted=-0.026857, expected=-0.093393
# predicted=-0.093393, expected=-0.053932
# predicted=-0.053932, expected=-0.086866
# predicted=-0.086866, expected=-0.013911
# predicted=-0.013911, expected=0.010316
# predicted=0.010316, expected=-0.041416
# predicted=-0.041416, expected=-0.083266
# predicted=-0.083266, expected=-0.094827
# predicted=-0.094827, expected=0.822647
# predicted=0.822647, expected=-0.073834
# predicted=-0.073834, expected=-0.060695
# predicted=-0.060695, expected=0.056132
# predicted=0.056132, expected=-0.052626
# predicted=-0.052626, expected=0.006300
# predicted=0.006300, expected=-0.098420
# predicted=-0.098420, expected=-0.093041
# predicted=-0.093041, expected=-0.061599
# predicted=-0.061599, expected=-0.045339
# predicted=-0.045339, expected=-0.093091
# predicted=-0.093091, expected=-0.089900
# predicted=-0.089900, expected=-0.094956
# predicted=-0.094956, expected=-0.068979
# predicted=-0.068979, expected=-0.049929
# predicted=-0.049929, expected=0.018744
# predicted=0.018744, expected=-0.074014
# predicted=-0.074014, expected=-0.032975
# predicted=-0.032975, expected=-0.090990
# predicted=-0.090990, expected=-0.074265
# predicted=-0.074265, expected=-0.085073
# predicted=-0.085073, expected=-0.089792
# predicted=-0.089792, expected=-0.070435
# predicted=-0.070435, expected=-0.084772
# predicted=-0.084772, expected=-0.093393
# predicted=-0.093393, expected=-0.098191
# predicted=-0.098191, expected=-0.031160
# predicted=-0.031160, expected=0.038589
# predicted=0.038589, expected=0.284306
# predicted=0.284306, expected=-0.097574
# predicted=-0.097574, expected=-0.094884
# predicted=-0.094884, expected=-0.093091
# predicted=-0.093091, expected=-0.088365
# predicted=-0.088365, expected=-0.019864
# predicted=-0.019864, expected=-0.084162
# predicted=-0.084162, expected=-0.095243
# predicted=-0.095243, expected=0.139716
# predicted=0.139716, expected=-0.071503
# predicted=-0.071503, expected=-0.065407
# predicted=-0.065407, expected=-0.042456
# predicted=-0.042456, expected=-0.065264
# predicted=-0.065264, expected=-0.120704
# predicted=-0.120704, expected=-0.068075
# predicted=-0.068075, expected=-0.008747
# predicted=-0.008747, expected=-0.096247
# predicted=-0.096247, expected=-0.068161
# predicted=-0.068161, expected=-0.086206
# predicted=-0.086206, expected=-0.074351
# predicted=-0.074351, expected=-0.084485
# predicted=-0.084485, expected=-0.022374
# predicted=-0.022374, expected=-0.058235
# predicted=-0.058235, expected=-0.091470
# predicted=-0.091470, expected=-0.083344
# predicted=-0.083344, expected=-0.091958
# predicted=-0.091958, expected=-0.093751
# predicted=-0.093751, expected=-0.077600
# predicted=-0.077600, expected=-0.038117
# predicted=-0.038117, expected=-0.044916
# predicted=-0.044916, expected=-0.077600
# predicted=-0.077600, expected=-0.095530
# predicted=-0.095530, expected=-0.048746
# predicted=-0.048746, expected=-0.086206
# predicted=-0.086206, expected=-0.081100
# predicted=-0.081100, expected=-0.097108
# predicted=-0.097108, expected=-0.064152
# predicted=-0.064152, expected=-0.024884
# predicted=-0.024884, expected=0.292483
# predicted=0.292483, expected=-0.014700
# predicted=-0.014700, expected=-0.104847
# predicted=-0.104847, expected=-0.091614
# predicted=-0.091614, expected=-0.002471
# predicted=-0.002471, expected=-0.082556
# predicted=-0.082556, expected=-0.084786
# predicted=-0.084786, expected=0.011650
# predicted=0.011650, expected=-0.087110
# predicted=-0.087110, expected=-0.052497
# predicted=-0.052497, expected=-0.084779
# predicted=-0.084779, expected=-0.077607
# predicted=-0.077607, expected=-0.093873
# predicted=-0.093873, expected=-0.052820
# predicted=-0.052820, expected=-0.094892
# predicted=-0.094892, expected=-0.097251
# predicted=-0.097251, expected=-0.101985
# predicted=-0.101985, expected=0.015803
# predicted=0.015803, expected=-0.087253
# predicted=-0.087253, expected=-0.023307
# predicted=-0.023307, expected=-0.076258
# predicted=-0.076258, expected=-0.080913
# predicted=-0.080913, expected=0.122718
# predicted=0.122718, expected=-0.107213
# predicted=-0.107213, expected=-0.064869
# predicted=-0.064869, expected=0.101374
# predicted=0.101374, expected=0.101374
# predicted=0.101374, expected=-0.099740
# predicted=-0.099740, expected=-0.092675
# predicted=-0.092675, expected=-0.090588
# predicted=-0.090588, expected=-0.092281
# predicted=-0.092281, expected=-0.020179
# predicted=-0.020179, expected=-0.058902
# predicted=-0.058902, expected=0.000440
# predicted=0.000440, expected=-0.084843
# predicted=-0.084843, expected=-0.082713
# predicted=-0.082713, expected=-0.081329
# predicted=-0.081329, expected=-0.081186
# predicted=-0.081186, expected=-0.052139
# predicted=-0.052139, expected=0.012913
# predicted=0.012913, expected=-0.057030
# predicted=-0.057030, expected=-0.043460
# predicted=-0.043460, expected=-0.096498
# predicted=-0.096498, expected=-0.028937
# predicted=-0.028937, expected=-0.094813
# predicted=-0.094813, expected=-0.091155
# predicted=-0.091155, expected=-0.093529
# predicted=-0.093529, expected=-0.075972
# predicted=-0.075972, expected=-0.062997
# predicted=-0.062997, expected=-0.081551
# predicted=-0.081551, expected=-0.068405
# predicted=-0.068405, expected=-0.079615
# predicted=-0.079615, expected=-0.065816
# predicted=-0.065816, expected=-0.070427
# predicted=-0.070427, expected=-0.079766
# predicted=-0.079766, expected=-0.092231
# predicted=-0.092231, expected=-0.064116
# predicted=-0.064116, expected=0.153343
# predicted=0.153343, expected=-0.084757
# predicted=-0.084757, expected=-0.048387
# predicted=-0.048387, expected=-0.024569
# predicted=-0.024569, expected=-0.060738
# predicted=-0.060738, expected=0.021197
# predicted=0.021197, expected=0.073015
# predicted=0.073015, expected=-0.095171
# predicted=-0.095171, expected=-0.095100
# predicted=-0.095100, expected=-0.068061
# predicted=-0.068061, expected=-0.093801
# predicted=-0.093801, expected=-0.074014
# predicted=-0.074014, expected=0.010618
# predicted=0.010618, expected=-0.082756
# predicted=-0.082756, expected=-0.006266
# predicted=-0.006266, expected=-0.089677
# predicted=-0.089677, expected=-0.097395
# predicted=-0.097395, expected=-0.073999
# predicted=-0.073999, expected=-0.073339
# predicted=-0.073339, expected=-0.084772
# predicted=-0.084772, expected=-0.091298
# predicted=-0.091298, expected=-0.066920
# predicted=-0.066920, expected=-0.019541
# predicted=-0.019541, expected=-0.064697
# predicted=-0.064697, expected=-0.090445
# predicted=-0.090445, expected=-0.081975
# predicted=-0.081975, expected=-0.058952
# predicted=-0.058952, expected=-0.086737
# predicted=-0.086737, expected=-0.025602
# predicted=-0.025602, expected=-0.053881
# predicted=-0.053881, expected=-0.073332
# predicted=-0.073332, expected=-0.051127
# predicted=-0.051127, expected=-0.068125
# predicted=-0.068125, expected=-0.079048
# predicted=-0.079048, expected=0.084347
# predicted=0.084347, expected=0.213438
# predicted=0.213438, expected=0.065427
# predicted=0.065427, expected=-0.081193
# predicted=-0.081193, expected=-0.077894
# predicted=-0.077894, expected=-0.097689
# predicted=-0.097689, expected=-0.094060
# predicted=-0.094060, expected=-0.082441
# predicted=-0.082441, expected=-0.056083
# predicted=-0.056083, expected=-0.071159
# predicted=-0.071159, expected=-0.063707
# predicted=-0.063707, expected=-0.067415
# predicted=-0.067415, expected=-0.084822
# predicted=-0.084822, expected=-0.031361
# predicted=-0.031361, expected=-0.060150
# predicted=-0.060150, expected=0.116048
# predicted=0.116048, expected=-0.112406
# predicted=-0.112406, expected=-0.079522
# predicted=-0.079522, expected=-0.066325
# predicted=-0.066325, expected=-0.093134
# predicted=-0.093134, expected=-0.002909
# predicted=-0.002909, expected=-0.079393
# predicted=-0.079393, expected=-0.096964
# predicted=-0.096964, expected=-0.063262
# predicted=-0.063262, expected=0.026346
# predicted=0.026346, expected=-0.094397
# predicted=-0.094397, expected=-0.065730
# predicted=-0.065730, expected=0.040741
# predicted=0.040741, expected=-0.068606
# predicted=-0.068606, expected=0.044327
# predicted=0.044327, expected=-0.077592
# predicted=-0.077592, expected=-0.046759
# predicted=-0.046759, expected=-0.094813
# predicted=-0.094813, expected=-0.063255
# predicted=-0.063255, expected=-0.083373
# predicted=-0.083373, expected=-0.083323
# predicted=-0.083323, expected=-0.081193
# predicted=-0.081193, expected=-0.066131
# predicted=-0.066131, expected=-0.080483
# predicted=-0.080483, expected=-0.059669
# predicted=-0.059669, expected=-0.061175
# predicted=-0.061175, expected=0.087360
# predicted=0.087360, expected=-0.069309
# predicted=-0.069309, expected=-0.094813
# predicted=-0.094813, expected=-0.078819
# predicted=-0.078819, expected=-0.084772
# predicted=-0.084772, expected=-0.088358
# predicted=-0.088358, expected=-0.093744
# predicted=-0.093744, expected=0.116048
# predicted=0.116048, expected=-0.096305
# predicted=-0.096305, expected=-0.086938
# predicted=-0.086938, expected=-0.039257
# predicted=-0.039257, expected=-0.054692
# predicted=-0.054692, expected=-0.090395
# predicted=-0.090395, expected=-0.057518
# predicted=-0.057518, expected=-0.088379
# predicted=-0.088379, expected=-0.082921
# predicted=-0.082921, expected=-0.093658
# predicted=-0.093658, expected=-0.008747
# predicted=-0.008747, expected=-0.014255
# predicted=-0.014255, expected=-0.099683
# predicted=-0.099683, expected=-0.052856
# predicted=-0.052856, expected=-0.051063
# predicted=-0.051063, expected=-0.080511
# predicted=-0.080511, expected=-0.020954
# predicted=-0.020954, expected=0.068970
# predicted=0.068970, expected=-0.097395
# predicted=-0.097395, expected=-0.068025
# predicted=-0.068025, expected=-0.054391
# predicted=-0.054391, expected=-0.091011
# predicted=-0.091011, expected=-0.093027
# predicted=-0.093027, expected=-0.096900
# predicted=-0.096900, expected=-0.008747
# predicted=-0.008747, expected=-0.095673
# predicted=-0.095673, expected=0.071208
# predicted=0.071208, expected=-0.092769
# predicted=-0.092769, expected=-0.045906
# predicted=-0.045906, expected=0.021290
# predicted=0.021290, expected=0.022237
# predicted=0.022237, expected=0.239983
# predicted=0.239983, expected=0.065843
# predicted=0.065843, expected=-0.020223
# predicted=-0.020223, expected=-0.086629
# predicted=-0.086629, expected=-0.046523
# predicted=-0.046523, expected=-0.074200
# predicted=-0.074200, expected=-0.073440
# predicted=-0.073440, expected=-0.050518
# predicted=-0.050518, expected=-0.088673
# predicted=-0.088673, expected=-0.063255
# predicted=-0.063255, expected=-0.076072
# predicted=-0.076072, expected=-0.054383
# predicted=-0.054383, expected=0.027020
# predicted=0.027020, expected=-0.069760
# predicted=-0.069760, expected=-0.074874
# predicted=-0.074874, expected=-0.091585
# predicted=-0.091585, expected=-0.094992
# predicted=-0.094992, expected=-0.091011
# predicted=-0.091011, expected=-0.081910
# predicted=-0.081910, expected=-0.037852
# predicted=-0.037852, expected=-0.082577
# predicted=-0.082577, expected=-0.065163
# predicted=-0.065163, expected=-0.047096
# predicted=-0.047096, expected=-0.082197
# predicted=-0.082197, expected=-0.081910
# predicted=-0.081910, expected=-0.080411
# predicted=-0.080411, expected=-0.078647
# predicted=-0.078647, expected=-0.083352
# predicted=-0.083352, expected=-0.077607
# predicted=-0.077607, expected=-0.067573
# predicted=-0.067573, expected=-0.061448
# predicted=-0.061448, expected=-0.061771
# predicted=-0.061771, expected=-0.079579
# predicted=-0.079579, expected=-0.042406
# predicted=-0.042406, expected=-0.089792
# predicted=-0.089792, expected=0.116048
# predicted=0.116048, expected=-0.076524
# predicted=-0.076524, expected=-0.001776
# predicted=-0.001776, expected=-0.095982
# predicted=-0.095982, expected=-0.061771
# predicted=-0.061771, expected=0.018306
# predicted=0.018306, expected=-0.082441
# predicted=-0.082441, expected=-0.094110
# predicted=-0.094110, expected=-0.086923
# predicted=-0.086923, expected=-0.084779
# predicted=-0.084779, expected=-0.070069
# predicted=-0.070069, expected=-0.096857
# predicted=-0.096857, expected=-0.039860
# predicted=-0.039860, expected=-0.074781
# predicted=-0.074781, expected=-0.053487
# predicted=-0.053487, expected=-0.090509
# predicted=-0.090509, expected=0.169839
# predicted=0.169839, expected=-0.063255
# predicted=-0.063255, expected=-0.038325
# predicted=-0.038325, expected=-0.088358
# predicted=-0.088358, expected=-0.088358
# predicted=-0.088358, expected=-0.089434
# predicted=-0.089434, expected=0.573315
# predicted=0.573315, expected=-0.078747
# predicted=-0.078747, expected=-0.097875
# predicted=-0.097875, expected=-0.025243
# predicted=-0.025243, expected=0.012748
# predicted=0.012748, expected=-0.095401
# predicted=-0.095401, expected=-0.002938
# predicted=-0.002938, expected=-0.086651
# predicted=-0.086651, expected=-0.087461
# predicted=-0.087461, expected=-0.069531
# predicted=-0.069531, expected=-0.069588
# predicted=-0.069588, expected=-0.089183
# predicted=-0.089183, expected=-0.057525
# predicted=-0.057525, expected=-0.060386
# predicted=-0.060386, expected=-0.077270
# predicted=-0.077270, expected=-0.082807
# predicted=-0.082807, expected=-0.051091
# predicted=-0.051091, expected=0.266605
# predicted=0.266605, expected=0.021376
# predicted=0.021376, expected=-0.091951
# predicted=-0.091951, expected=-0.063757
# predicted=-0.063757, expected=0.223630
# predicted=0.223630, expected=0.081622
# predicted=0.081622, expected=-0.070435
# predicted=-0.070435, expected=-0.047477
# predicted=-0.047477, expected=0.080187
# predicted=0.080187, expected=-0.090509
# predicted=-0.090509, expected=-0.088358
# predicted=-0.088358, expected=-0.080569
# predicted=-0.080569, expected=-0.080124
# predicted=-0.080124, expected=-0.090223
# predicted=-0.090223, expected=0.177011
# predicted=0.177011, expected=0.008459
# predicted=0.008459, expected=-0.032437
# predicted=-0.032437, expected=-0.087841
# predicted=-0.087841, expected=-0.074372
# predicted=-0.074372, expected=-0.091262
# predicted=-0.091262, expected=-0.059189
# predicted=-0.059189, expected=-0.069968
# predicted=-0.069968, expected=-0.096613
# predicted=-0.096613, expected=-0.089018
# predicted=-0.089018, expected=-0.044235
# predicted=-0.044235, expected=-0.048352
# predicted=-0.048352, expected=-0.097832
# predicted=-0.097832, expected=0.005239
# predicted=0.005239, expected=-0.064073
# predicted=-0.064073, expected=-0.096032
# predicted=-0.096032, expected=-0.056083
# predicted=-0.056083, expected=-0.074014
# predicted=-0.074014, expected=-0.090517
# predicted=-0.090517, expected=-0.088143
# predicted=-0.088143, expected=-0.057553
# predicted=-0.057553, expected=-0.095645
# predicted=-0.095645, expected=-0.079063
# predicted=-0.079063, expected=0.022380
# predicted=0.022380, expected=-0.075914
# predicted=-0.075914, expected=-0.081917
# predicted=-0.081917, expected=-0.044873
# predicted=-0.044873, expected=-0.077600
# predicted=-0.077600, expected=-0.089218
# predicted=-0.089218, expected=-0.165817
# predicted=-0.165817, expected=-0.032415
# predicted=-0.032415, expected=-0.064489
# predicted=-0.064489, expected=-0.094110
# predicted=-0.094110, expected=-0.086938
# predicted=-0.086938, expected=-0.090918
# predicted=-0.090918, expected=-0.083208
# predicted=-0.083208, expected=-0.014815
# predicted=-0.014815, expected=-0.051113
# predicted=-0.051113, expected=-0.010899
# predicted=-0.010899, expected=-0.088193
# predicted=-0.088193, expected=-0.089233
# predicted=-0.089233, expected=-0.041768
# predicted=-0.041768, expected=-0.077478
# predicted=-0.077478, expected=-0.097273
# predicted=-0.097273, expected=-0.086385
# predicted=-0.086385, expected=-0.094131
# predicted=-0.094131, expected=-0.096735
# predicted=-0.096735, expected=-0.095566
# predicted=-0.095566, expected=-0.086199
# predicted=-0.086199, expected=-0.077607
# predicted=-0.077607, expected=0.114614
# predicted=0.114614, expected=-0.051063
# predicted=-0.051063, expected=-0.046200
# predicted=-0.046200, expected=-0.094884
# predicted=-0.094884, expected=1.992278
# predicted=1.992278, expected=-0.086945
# predicted=-0.086945, expected=-0.016565
# predicted=-0.016565, expected=-0.084779
# predicted=-0.084779, expected=-0.071948
# predicted=-0.071948, expected=0.021017
# predicted=0.021017, expected=0.089511
# predicted=0.089511, expected=-0.087217
# predicted=-0.087217, expected=-0.016644
# predicted=-0.016644, expected=0.038589
# predicted=0.038589, expected=0.073869
# predicted=0.073869, expected=-0.076409
# predicted=-0.076409, expected=-0.088716
# predicted=-0.088716, expected=0.027314
# predicted=0.027314, expected=-0.099338
# predicted=-0.099338, expected=-0.059447
# predicted=-0.059447, expected=0.029982
# predicted=0.029982, expected=-0.089075
# predicted=-0.089075, expected=0.079470
# predicted=0.079470, expected=-0.090667
# predicted=-0.090667, expected=-0.065479
# predicted=-0.065479, expected=-0.061104
# predicted=-0.061104, expected=-0.088358
# predicted=-0.088358, expected=-0.034760
# predicted=-0.034760, expected=-0.094884
# predicted=-0.094884, expected=-0.094203
# predicted=-0.094203, expected=-0.053071
# predicted=-0.053071, expected=-0.095537
# predicted=-0.095537, expected=-0.046214
# predicted=-0.046214, expected=-0.067401
# predicted=-0.067401, expected=-0.061434
# predicted=-0.061434, expected=-0.091227
# predicted=-0.091227, expected=-0.043898
# predicted=-0.043898, expected=-0.090050
# predicted=-0.090050, expected=-0.090517
# predicted=-0.090517, expected=-0.065443
# predicted=-0.065443, expected=0.015631
# predicted=0.015631, expected=0.094532
# predicted=0.094532, expected=-0.058809
# predicted=-0.058809, expected=-0.050726
# predicted=-0.050726, expected=-0.099977
# predicted=-0.099977, expected=-0.022059
# predicted=-0.022059, expected=-0.092654
# predicted=-0.092654, expected=-0.105191
# predicted=-0.105191, expected=0.043990
# predicted=0.043990, expected=-0.097330
# predicted=-0.097330, expected=-0.092310
# predicted=-0.092310, expected=-0.088143
# predicted=-0.088143, expected=-0.041760
# predicted=-0.041760, expected=-0.082706
# predicted=-0.082706, expected=-0.031719
# predicted=-0.031719, expected=-0.077671
# predicted=-0.077671, expected=-0.085503
# predicted=-0.085503, expected=-0.080612
# predicted=-0.080612, expected=-0.095028
# predicted=-0.095028, expected=-0.051938
# predicted=-0.051938, expected=-0.094777
# predicted=-0.094777, expected=-0.095214
# predicted=-0.095214, expected=0.017073
# predicted=0.017073, expected=-0.066863
# predicted=-0.066863, expected=-0.091399
# predicted=-0.091399, expected=-0.088745
# predicted=-0.088745, expected=-0.087067
# predicted=-0.087067, expected=-0.083409
# predicted=-0.083409, expected=-0.063255
# predicted=-0.063255, expected=-0.001224
# predicted=-0.001224, expected=-0.030307
# predicted=-0.030307, expected=-0.062481
# predicted=-0.062481, expected=-0.101978
# predicted=-0.101978, expected=-0.074014
# predicted=-0.074014, expected=-0.095171
# predicted=-0.095171, expected=0.079900
# predicted=0.079900, expected=-0.072292
# predicted=-0.072292, expected=-0.063320
# predicted=-0.063320, expected=-0.071747
# predicted=-0.071747, expected=-0.060386
# predicted=-0.060386, expected=-0.095458
# predicted=-0.095458, expected=0.123421
# predicted=0.123421, expected=-0.024770
# predicted=-0.024770, expected=-0.027603
# predicted=-0.027603, expected=-0.093701
# predicted=-0.093701, expected=-0.083753
# predicted=-0.083753, expected=-0.092338
# predicted=-0.092338, expected=-0.072163
# predicted=-0.072163, expected=-0.042829
# predicted=-0.042829, expected=-0.068878
# predicted=-0.068878, expected=0.029932
# predicted=0.029932, expected=-0.079615
# predicted=-0.079615, expected=-0.077650
# predicted=-0.077650, expected=-0.097122
# predicted=-0.097122, expected=-0.095530
# predicted=-0.095530, expected=-0.052497
# predicted=-0.052497, expected=-0.080476
# predicted=-0.080476, expected=-0.075125
# predicted=-0.075125, expected=0.026382
# predicted=0.026382, expected=-0.083689
# predicted=-0.083689, expected=-0.085353
# predicted=-0.085353, expected=-0.077800
# predicted=-0.077800, expected=-0.076466
# predicted=-0.076466, expected=-0.084779
# predicted=-0.084779, expected=0.070111
# predicted=0.070111, expected=-0.077033
# predicted=-0.077033, expected=-0.073727
# predicted=-0.073727, expected=0.538688
# predicted=0.538688, expected=0.004163
# predicted=0.004163, expected=0.066560
# predicted=0.066560, expected=-0.095810
# predicted=-0.095810, expected=-0.094103
# predicted=-0.094103, expected=-0.088358
# predicted=-0.088358, expected=-0.083352
# predicted=-0.083352, expected=-0.034674
# predicted=-0.034674, expected=0.017732
# predicted=0.017732, expected=0.260172
# predicted=0.260172, expected=0.611607
# predicted=0.611607, expected=0.083974
# predicted=0.083974, expected=-0.081186
# predicted=-0.081186, expected=-0.084786
# predicted=-0.084786, expected=-0.088788
# predicted=-0.088788, expected=-0.055997
# predicted=-0.055997, expected=-0.091033
# predicted=-0.091033, expected=-0.084054
# predicted=-0.084054, expected=-0.060006
# predicted=-0.060006, expected=-0.049478
# predicted=-0.049478, expected=-0.092675
# predicted=-0.092675, expected=-0.057589
# predicted=-0.057589, expected=-0.092769
# predicted=-0.092769, expected=-0.091908
# predicted=-0.091908, expected=-0.091234
# predicted=-0.091234, expected=-0.070463
# predicted=-0.070463, expected=-0.070865
# predicted=-0.070865, expected=-0.091951
# predicted=-0.091951, expected=0.033884
# predicted=0.033884, expected=-0.101978
# predicted=-0.101978, expected=-0.090517
# predicted=-0.090517, expected=-0.093737
# predicted=-0.093737, expected=-0.093916
# predicted=-0.093916, expected=-0.004100
# predicted=-0.004100, expected=-0.081336
# predicted=-0.081336, expected=-0.067286
# predicted=-0.067286, expected=0.061196
# predicted=0.061196, expected=-0.090875
# predicted=-0.090875, expected=-0.092984
# predicted=-0.092984, expected=-0.091944
# predicted=-0.091944, expected=-0.073339
# predicted=-0.073339, expected=-0.085503
# predicted=-0.085503, expected=-0.033936
# predicted=-0.033936, expected=-0.091980
# predicted=-0.091980, expected=-0.083352
# predicted=-0.083352, expected=-0.088358
# predicted=-0.088358, expected=-0.096089
# predicted=-0.096089, expected=-0.027395
# predicted=-0.027395, expected=-0.061907
# predicted=-0.061907, expected=-0.041323
# predicted=-0.041323, expected=-0.076703
# predicted=-0.076703, expected=-0.086923
# predicted=-0.086923, expected=-0.086292
# predicted=-0.086292, expected=-0.031382
# predicted=-0.031382, expected=-0.068312
# predicted=-0.068312, expected=-0.016063
# predicted=-0.016063, expected=-0.094103
# predicted=-0.094103, expected=-0.078812
# predicted=-0.078812, expected=-0.030077
# predicted=-0.030077, expected=-0.058177
# predicted=-0.058177, expected=-0.075656
# predicted=-0.075656, expected=-0.063255
# predicted=-0.063255, expected=-0.087009
# predicted=-0.087009, expected=-0.069560
# predicted=-0.069560, expected=-0.070643
# predicted=-0.070643, expected=0.001724
# predicted=0.001724, expected=-0.029891
# predicted=-0.029891, expected=-0.091119
# predicted=-0.091119, expected=-0.043891
# predicted=-0.043891, expected=-0.046989
# predicted=-0.046989, expected=-0.092338
# predicted=-0.092338, expected=-0.095121
# predicted=-0.095121, expected=-0.052497
# predicted=-0.052497, expected=-0.047419
# predicted=-0.047419, expected=-0.095250
# predicted=-0.095250, expected=-0.090187
# predicted=-0.090187, expected=-0.095049
# predicted=-0.095049, expected=-0.097646
# predicted=-0.097646, expected=-0.037263
# predicted=-0.037263, expected=0.002621
# predicted=0.002621, expected=-0.087253
# predicted=-0.087253, expected=-0.007779
# predicted=-0.007779, expected=-0.077578
# predicted=-0.077578, expected=-0.077592
# predicted=-0.077592, expected=-0.092310
# predicted=-0.092310, expected=0.029767
# predicted=0.029767, expected=-0.082369
# predicted=-0.082369, expected=-0.027961
# predicted=-0.027961, expected=-0.084772
# predicted=-0.084772, expected=-0.086063
# predicted=-0.086063, expected=-0.045110
# predicted=-0.045110, expected=0.019224
# predicted=0.019224, expected=-0.083323
# predicted=-0.083323, expected=-0.063255
# predicted=-0.063255, expected=-0.096964
# predicted=-0.096964, expected=-0.005785
# predicted=-0.005785, expected=-0.087927
# predicted=-0.087927, expected=-0.090165
# predicted=-0.090165, expected=-0.060602
# predicted=-0.060602, expected=-0.075448
# predicted=-0.075448, expected=-0.029044
# predicted=-0.029044, expected=-0.095171
# predicted=-0.095171, expected=-0.096254
# predicted=-0.096254, expected=-0.048911
# predicted=-0.048911, expected=-0.073698
# predicted=-0.073698, expected=-0.070427
# predicted=-0.070427, expected=-0.052260
# predicted=-0.052260, expected=-0.113345
# predicted=-0.113345, expected=-0.076194
# predicted=-0.076194, expected=0.182319
# predicted=0.182319, expected=-0.084126
# predicted=-0.084126, expected=-0.066131
# predicted=-0.066131, expected=-0.050087
# predicted=-0.050087, expected=-0.046071
# predicted=-0.046071, expected=0.012045
# predicted=0.012045, expected=-0.091406
# predicted=-0.091406, expected=0.062257
# predicted=0.062257, expected=-0.074731
# predicted=-0.074731, expected=-0.038153
# predicted=-0.038153, expected=-0.087784
# predicted=-0.087784, expected=-0.081171
# predicted=-0.081171, expected=0.216458
# predicted=0.216458, expected=-0.072041
# predicted=-0.072041, expected=-0.034567
# predicted=-0.034567, expected=-0.097323
# predicted=-0.097323, expected=0.034286
# predicted=0.034286, expected=-0.087361
# predicted=-0.087361, expected=-0.051063
# predicted=-0.051063, expected=-0.084772
# predicted=-0.084772, expected=-0.047720
# predicted=-0.047720, expected=-0.093773
# predicted=-0.093773, expected=-0.094167
# predicted=-0.094167, expected=-0.084714
# predicted=-0.084714, expected=-0.083201
# predicted=-0.083201, expected=-0.082771
# predicted=-0.082771, expected=-0.061814
# predicted=-0.061814, expected=-0.061670
# predicted=-0.061670, expected=0.019863
# predicted=0.019863, expected=-0.067874
# predicted=-0.067874, expected=-0.079084
# predicted=-0.079084, expected=-0.049184
# predicted=-0.049184, expected=-0.098212
# predicted=-0.098212, expected=-0.072780
# predicted=-0.072780, expected=-0.053243
# predicted=-0.053243, expected=-0.094454
# predicted=-0.094454, expected=0.176294
# predicted=0.176294, expected=-0.078891
# predicted=-0.078891, expected=-0.090517
# predicted=-0.090517, expected=-0.077664
# predicted=-0.077664, expected=-0.088286
# predicted=-0.088286, expected=-0.090517
# predicted=-0.090517, expected=-0.063255
# predicted=-0.063255, expected=-0.064188
# predicted=-0.064188, expected=-0.062323
# predicted=-0.062323, expected=-0.095508
# predicted=-0.095508, expected=-0.092883
# predicted=-0.092883, expected=-0.073325
# predicted=-0.073325, expected=-0.048911
# predicted=-0.048911, expected=-0.095530
# predicted=-0.095530, expected=-0.032057
# predicted=-0.032057, expected=-0.085137
# predicted=-0.085137, expected=-0.088372
# predicted=-0.088372, expected=-0.095530
# predicted=-0.095530, expected=-0.047505
# predicted=-0.047505, expected=-0.027760
# predicted=-0.027760, expected=-0.048968
# predicted=-0.048968, expected=0.072635
# predicted=0.072635, expected=-0.091621
# predicted=-0.091621, expected=-0.017074
# predicted=-0.017074, expected=-0.093020
# predicted=-0.093020, expected=-0.094454
# predicted=-0.094454, expected=-0.077076
# predicted=-0.077076, expected=-0.034890
# predicted=-0.034890, expected=-0.097696
# predicted=-0.097696, expected=-0.066124
# predicted=-0.066124, expected=-0.094827
# predicted=-0.094827, expected=-0.036001
# predicted=-0.036001, expected=-0.093393
# predicted=-0.093393, expected=-0.097251
# predicted=-0.097251, expected=-0.096362
# predicted=-0.096362, expected=-0.060014
# predicted=-0.060014, expected=-0.069337
# predicted=-0.069337, expected=0.139716
# predicted=0.139716, expected=-0.052540
# predicted=-0.052540, expected=-0.082692
# predicted=-0.082692, expected=-0.063255
# predicted=-0.063255, expected=-0.088358
# predicted=-0.088358, expected=-0.085668
# predicted=-0.085668, expected=-0.086472
# predicted=-0.086472, expected=-0.096247
# predicted=-0.096247, expected=-0.070456
# predicted=-0.070456, expected=0.364383
# predicted=0.364383, expected=-0.088860
# predicted=-0.088860, expected=-0.060293
# predicted=-0.060293, expected=-0.091944
# predicted=-0.091944, expected=-0.063872
# predicted=-0.063872, expected=-0.059669
# predicted=-0.059669, expected=-0.064188
# predicted=-0.064188, expected=-0.084463
# predicted=-0.084463, expected=-0.092934
# predicted=-0.092934, expected=-0.093694
# predicted=-0.093694, expected=0.092523
# predicted=0.092523, expected=-0.086981
# predicted=-0.086981, expected=-0.055581
# predicted=-0.055581, expected=0.277421
# predicted=0.277421, expected=-0.074946
# predicted=-0.074946, expected=-0.063973
# predicted=-0.063973, expected=0.059388
# predicted=0.059388, expected=0.001904
# predicted=0.001904, expected=-0.053422
# predicted=-0.053422, expected=-0.084126
# predicted=-0.084126, expected=-0.064690
# predicted=-0.064690, expected=-0.056126
# predicted=-0.056126, expected=-0.088358
# predicted=-0.088358, expected=-0.077600
# predicted=-0.077600, expected=-0.095351
# predicted=-0.095351, expected=-0.069717
# predicted=-0.069717, expected=-0.063944
# predicted=-0.063944, expected=-0.066124
# predicted=-0.066124, expected=-0.078683
# predicted=-0.078683, expected=-0.082850
# predicted=-0.082850, expected=-0.070592
# predicted=-0.070592, expected=-0.092209
# predicted=-0.092209, expected=-0.069746
# predicted=-0.069746, expected=0.025679
# predicted=0.025679, expected=-0.069531
# predicted=-0.069531, expected=0.170915
# predicted=0.170915, expected=-0.015367
# predicted=-0.015367, expected=-0.093378
# predicted=-0.093378, expected=-0.096972
# predicted=-0.096972, expected=0.090228
# predicted=0.090228, expected=-0.016012
# predicted=-0.016012, expected=-0.077420
# predicted=-0.077420, expected=-0.074745
# predicted=-0.074745, expected=-0.027416
# predicted=-0.027416, expected=-0.073942
# predicted=-0.073942, expected=0.022810
# predicted=0.022810, expected=-0.076165
# predicted=-0.076165, expected=-0.073576
# predicted=-0.073576, expected=-0.067028
# predicted=-0.067028, expected=0.091778
# predicted=0.091778, expected=-0.054663
# predicted=-0.054663, expected=-0.097093
# predicted=-0.097093, expected=-0.085690
# predicted=-0.085690, expected=-0.093385
# predicted=-0.093385, expected=-0.091958
# predicted=-0.091958, expected=-0.094827
# predicted=-0.094827, expected=-0.097782
# predicted=-0.097782, expected=0.094517
# predicted=0.094517, expected=0.008466
# predicted=0.008466, expected=-0.074014
# predicted=-0.074014, expected=0.011048
# predicted=0.011048, expected=0.063548
# predicted=0.063548, expected=-0.072593
# predicted=-0.072593, expected=-0.050783
# predicted=-0.050783, expected=-0.097875
# predicted=-0.097875, expected=-0.066153
# predicted=-0.066153, expected=-0.093378
# predicted=-0.093378, expected=-0.070427
# predicted=-0.070427, expected=-0.070284
# predicted=-0.070284, expected=-0.096319
# predicted=-0.096319, expected=-0.078661
# predicted=-0.078661, expected=-0.158638
# predicted=-0.158638, expected=0.111314
# predicted=0.111314, expected=-0.035635
# predicted=-0.035635, expected=-0.027179
# predicted=-0.027179, expected=-0.032960
# predicted=-0.032960, expected=-0.086593
# predicted=-0.086593, expected=0.013178
# predicted=0.013178, expected=-0.089075
# predicted=-0.089075, expected=-0.090868
# predicted=-0.090868, expected=-0.077958
# predicted=-0.077958, expected=-0.085252
# predicted=-0.085252, expected=-0.069344
# predicted=-0.069344, expected=-0.080841
# predicted=-0.080841, expected=-0.077614
# predicted=-0.077614, expected=-0.084054
# predicted=-0.084054, expected=-0.091822
# predicted=-0.091822, expected=-0.094856
# predicted=-0.094856, expected=-0.059533
# predicted=-0.059533, expected=-0.075018
# predicted=-0.075018, expected=-0.077786
# predicted=-0.077786, expected=-0.055653
# predicted=-0.055653, expected=-0.095530
# predicted=-0.095530, expected=-0.088458
# predicted=-0.088458, expected=-0.086213
# predicted=-0.086213, expected=-0.098040
# predicted=-0.098040, expected=-0.059167
# predicted=-0.059167, expected=-0.091463
# predicted=-0.091463, expected=-0.051945
# predicted=-0.051945, expected=-0.024633
# predicted=-0.024633, expected=-0.037464
# predicted=-0.037464, expected=-0.095537
# predicted=-0.095537, expected=-0.079823
# predicted=-0.079823, expected=-0.095308
# predicted=-0.095308, expected=-0.091836
# predicted=-0.091836, expected=-0.090517
# predicted=-0.090517, expected=0.061439
# predicted=0.061439, expected=0.017073
# predicted=0.017073, expected=-0.089118
# predicted=-0.089118, expected=-0.030981
# predicted=-0.030981, expected=-0.088358
# predicted=-0.088358, expected=-0.013122
# predicted=-0.013122, expected=-0.058809
# predicted=-0.058809, expected=-0.089649
# predicted=-0.089649, expected=-0.055036
# predicted=-0.055036, expected=-0.097101
# predicted=-0.097101, expected=-0.085812
# predicted=-0.085812, expected=-0.051012
# predicted=-0.051012, expected=-0.080468
# predicted=-0.080468, expected=-0.081559
# predicted=-0.081559, expected=-0.084779
# predicted=-0.084779, expected=-0.094820
# predicted=-0.094820, expected=-0.052504
# predicted=-0.052504, expected=-0.092166
# predicted=-0.092166, expected=-0.047735
# predicted=-0.047735, expected=-0.089441
# predicted=-0.089441, expected=-0.044751
# predicted=-0.044751, expected=-0.093672
# predicted=-0.093672, expected=-0.094275
# predicted=-0.094275, expected=-0.094849
# predicted=-0.094849, expected=0.623261
# predicted=0.623261, expected=-0.091227
# predicted=-0.091227, expected=-0.096254
# predicted=-0.096254, expected=0.124647
# predicted=0.124647, expected=-0.095688
# predicted=-0.095688, expected=-0.086228
# predicted=-0.086228, expected=0.126792
# predicted=0.126792, expected=-0.082907
# predicted=-0.082907, expected=-0.097373
# predicted=-0.097373, expected=-0.083488
# predicted=-0.083488, expected=0.041938
# predicted=0.041938, expected=-0.040383
# predicted=-0.040383, expected=-0.082964
# predicted=-0.082964, expected=-0.078747
# predicted=-0.078747, expected=-0.013732
# predicted=-0.013732, expected=-0.094103
# predicted=-0.094103, expected=-0.089828
# predicted=-0.089828, expected=-0.084772
# predicted=-0.084772, expected=-0.084069
# predicted=-0.084069, expected=-0.077614
# predicted=-0.077614, expected=0.090228
# predicted=0.090228, expected=-0.091241
# predicted=-0.091241, expected=-0.088932
# predicted=-0.088932, expected=-0.048144
# predicted=-0.048144, expected=-0.087103
# predicted=-0.087103, expected=-0.084786
# predicted=-0.084786, expected=-0.093385
# predicted=-0.093385, expected=-0.082842
# predicted=-0.082842, expected=-0.074724
# predicted=-0.074724, expected=-0.096756
# predicted=-0.096756, expected=-0.096068
# predicted=-0.096068, expected=0.024216
# predicted=0.024216, expected=-0.096068
# predicted=-0.096068, expected=-0.089799
# predicted=-0.089799, expected=0.083207
# predicted=0.083207, expected=-0.083309
# predicted=-0.083309, expected=-0.049643
# predicted=-0.049643, expected=-0.034782
# predicted=-0.034782, expected=-0.087619
# predicted=-0.087619, expected=-0.058880
# predicted=-0.058880, expected=-0.056098
# predicted=-0.056098, expected=-0.088408
# predicted=-0.088408, expected=-0.068283
# predicted=-0.068283, expected=-0.109114
# predicted=-0.109114, expected=-0.081688
# predicted=-0.081688, expected=-0.052504
# predicted=-0.052504, expected=0.019698
# predicted=0.019698, expected=0.018579
# predicted=0.018579, expected=-0.022016
# predicted=-0.022016, expected=-0.005391
# predicted=-0.005391, expected=-0.069925
# predicted=-0.069925, expected=-0.094454
# predicted=-0.094454, expected=-0.069581
# predicted=-0.069581, expected=-0.075362
# predicted=-0.075362, expected=-0.092044
# predicted=-0.092044, expected=-0.064711
# predicted=-0.064711, expected=-0.092338
# predicted=-0.092338, expected=-0.081243
# predicted=-0.081243, expected=-0.078123
# predicted=-0.078123, expected=-0.045827
# predicted=-0.045827, expected=-0.055036
# predicted=-0.055036, expected=-0.094547
# predicted=-0.094547, expected=-0.073447
# predicted=-0.073447, expected=-0.082591
# predicted=-0.082591, expected=-0.070714
# predicted=-0.070714, expected=-0.087461
# predicted=-0.087461, expected=-0.041918
# predicted=-0.041918, expected=-0.091944
# predicted=-0.091944, expected=-0.091944
# predicted=-0.091944, expected=-0.095566
# predicted=-0.095566, expected=-0.098306
# predicted=-0.098306, expected=-0.053071
# predicted=-0.053071, expected=-0.098011
# predicted=-0.098011, expected=-0.072385
# predicted=-0.072385, expected=-0.091958
# predicted=-0.091958, expected=-0.086959
# predicted=-0.086959, expected=-0.071181
# predicted=-0.071181, expected=-0.065299
# predicted=-0.065299, expected=-0.095716
# predicted=-0.095716, expected=0.030951
# predicted=0.030951, expected=-0.089441
# predicted=-0.089441, expected=-0.091958
# predicted=-0.091958, expected=-0.084994
# predicted=-0.084994, expected=-0.074688
# predicted=-0.074688, expected=0.097544
# predicted=0.097544, expected=-0.093385
# predicted=-0.093385, expected=-0.049069
# predicted=-0.049069, expected=-0.072149
# predicted=-0.072149, expected=-0.014277
# predicted=-0.014277, expected=-0.072880
# predicted=-0.072880, expected=-0.068663
# predicted=-0.068663, expected=0.022344
# predicted=0.022344, expected=-0.094095
# predicted=-0.094095, expected=0.120351
# predicted=0.120351, expected=-0.075663
# predicted=-0.075663, expected=-0.022948
# predicted=-0.022948, expected=-0.090029
# predicted=-0.090029, expected=-0.084886
# predicted=-0.084886, expected=-0.063277
# predicted=-0.063277, expected=-0.092245
# predicted=-0.092245, expected=-0.064008
# predicted=-0.064008, expected=-0.081186
# predicted=-0.081186, expected=-0.071804
# predicted=-0.071804, expected=-0.089290
# predicted=-0.089290, expected=-0.085489
# predicted=-0.085489, expected=-0.058809
# predicted=-0.058809, expected=-0.023163
# predicted=-0.023163, expected=-0.076760
# predicted=-0.076760, expected=0.042713
# predicted=0.042713, expected=-0.080468
# predicted=-0.080468, expected=-0.042922
# predicted=-0.042922, expected=-0.083825
# predicted=-0.083825, expected=-0.047728
# predicted=-0.047728, expected=-0.041746
# predicted=-0.041746, expected=-0.049736
# predicted=-0.049736, expected=-0.084829
# predicted=-0.084829, expected=-0.065909
# predicted=-0.065909, expected=-0.056514
# predicted=-0.056514, expected=-0.058952
# predicted=-0.058952, expected=-0.089799
# predicted=-0.089799, expected=-0.099259
# predicted=-0.099259, expected=-0.091621
# predicted=-0.091621, expected=-0.091413
# predicted=-0.091413, expected=0.005239
# predicted=0.005239, expected=-0.084915
# predicted=-0.084915, expected=-0.089276
# predicted=-0.089276, expected=-0.066131
# predicted=-0.066131, expected=-0.063255
# predicted=-0.063255, expected=-0.024719
# predicted=-0.024719, expected=-0.081308
# predicted=-0.081308, expected=-0.046021
# predicted=-0.046021, expected=0.015531
# predicted=0.015531, expected=-0.065407
# predicted=-0.065407, expected=-0.096534
# predicted=-0.096534, expected=-0.095537
# predicted=-0.095537, expected=-0.053336
# predicted=-0.053336, expected=-0.066655
# predicted=-0.066655, expected=-0.049915
# predicted=-0.049915, expected=-0.090710
# predicted=-0.090710, expected=-0.087354
# predicted=-0.087354, expected=0.110669
# predicted=0.110669, expected=-0.069352
# predicted=-0.069352, expected=-0.095207
# predicted=-0.095207, expected=-0.088358
# predicted=-0.088358, expected=-0.081308
# predicted=-0.081308, expected=-0.094827
# predicted=-0.094827, expected=-0.010182
# predicted=-0.010182, expected=-0.056126
# predicted=-0.056126, expected=-0.079572
# predicted=-0.079572, expected=-0.093307
# predicted=-0.093307, expected=-0.003734
# predicted=-0.003734, expected=-0.098808
# predicted=-0.098808, expected=-0.070427
# predicted=-0.070427, expected=-0.088594
# predicted=-0.088594, expected=-0.099475
# predicted=-0.099475, expected=-0.075326
# predicted=-0.075326, expected=-0.054383
# predicted=-0.054383, expected=0.116048
# predicted=0.116048, expected=-0.049535
# predicted=-0.049535, expected=-0.075326
# predicted=-0.075326, expected=-0.077600
# predicted=-0.077600, expected=-0.075326
# predicted=-0.075326, expected=-0.042456
# predicted=-0.042456, expected=-0.090273
# predicted=-0.090273, expected=-0.094820
# predicted=-0.094820, expected=-0.052741
# predicted=-0.052741, expected=-0.018802
# predicted=-0.018802, expected=0.618097
# predicted=0.618097, expected=-0.094454
# predicted=-0.094454, expected=-0.048739
# predicted=-0.048739, expected=-0.086070
# predicted=-0.086070, expected=-0.096505
# predicted=-0.096505, expected=-0.028521
# predicted=-0.028521, expected=-0.085489
# predicted=-0.085489, expected=-0.018967
# predicted=-0.018967, expected=-0.091951
# predicted=-0.091951, expected=-0.097423
# predicted=-0.097423, expected=0.017811
# predicted=0.017811, expected=-0.070485
# predicted=-0.070485, expected=-0.013058
# predicted=-0.013058, expected=-0.054591
# predicted=-0.054591, expected=0.024596
# predicted=0.024596, expected=-0.091198
# predicted=-0.091198, expected=-0.094813
# predicted=-0.094813, expected=-0.066153
# predicted=-0.066153, expected=-0.068132
# predicted=-0.068132, expected=-0.054125
# predicted=-0.054125, expected=-0.028829
# predicted=-0.028829, expected=0.040741
# predicted=0.040741, expected=-0.063255
# predicted=-0.063255, expected=-0.096190
# predicted=-0.096190, expected=-0.093658
# predicted=-0.093658, expected=-0.062968
# predicted=-0.062968, expected=-0.033706
# predicted=-0.033706, expected=-0.038160
# predicted=-0.038160, expected=-0.067401
# predicted=-0.067401, expected=-0.092475
# predicted=-0.092475, expected=-0.096247
# predicted=-0.096247, expected=-0.061297
# predicted=-0.061297, expected=-0.085919
# predicted=-0.085919, expected=-0.092116
# predicted=-0.092116, expected=-0.046437
# predicted=-0.046437, expected=-0.093020
# predicted=-0.093020, expected=-0.039451
# predicted=-0.039451, expected=-0.101268
# predicted=-0.101268, expected=-0.087655
# predicted=-0.087655, expected=-0.091951
# predicted=-0.091951, expected=-0.074415
# predicted=-0.074415, expected=-0.077578
# predicted=-0.077578, expected=-0.024318
# predicted=-0.024318, expected=-0.061247
# predicted=-0.061247, expected=-0.061104
# predicted=-0.061104, expected=0.024926
# predicted=0.024926, expected=-0.069538
# predicted=-0.069538, expected=-0.069294
# predicted=-0.069294, expected=-0.094813
# predicted=-0.094813, expected=-0.065228
# predicted=-0.065228, expected=-0.093737
# predicted=-0.093737, expected=-0.086077
# predicted=-0.086077, expected=-0.088637
# predicted=-0.088637, expected=-0.092202
# predicted=-0.092202, expected=-0.079751
# predicted=-0.079751, expected=0.019239
# predicted=0.019239, expected=-0.091227
# predicted=-0.091227, expected=-0.027402
# predicted=-0.027402, expected=-0.008288
# predicted=-0.008288, expected=0.003933
# predicted=0.003933, expected=-0.061096
# predicted=-0.061096, expected=-0.086235
# predicted=-0.086235, expected=-0.046042
# predicted=-0.046042, expected=0.144019
# predicted=0.144019, expected=-0.063019
# predicted=-0.063019, expected=-0.086565
# predicted=-0.086565, expected=-0.059669
# predicted=-0.059669, expected=-0.093880
# predicted=-0.093880, expected=-0.090438
# predicted=-0.090438, expected=-0.083495
# predicted=-0.083495, expected=-0.096254
# predicted=-0.096254, expected=-0.068656
# predicted=-0.068656, expected=0.040741
# predicted=0.040741, expected=-0.074042
# predicted=-0.074042, expected=-0.020925
# predicted=-0.020925, expected=-0.083574
# ...
# predicted=-0.023163, expected=-0.090509
# predicted=-0.090509, expected=0.778646
# predicted=0.778646, expected=-0.072579
# predicted=-0.072579, expected=-0.062997
# predicted=-0.062997, expected=-0.041739
# predicted=-0.041739, expected=0.255474
# predicted=0.255474, expected=-0.027402
# predicted=-0.027402, expected=0.008416
# predicted=0.008416, expected=-0.076165
# predicted=-0.076165, expected=-0.077621
# predicted=-0.077621, expected=-0.070406
# predicted=-0.070406, expected=0.059288
# predicted=0.059288, expected=-0.094820
# predicted=-0.094820, expected=0.163169
# predicted=0.163169, expected=-0.437447
# predicted=-0.437447, expected=0.778646
# predicted=0.778646, expected=-0.098399
# predicted=-0.098399, expected=0.330423
# predicted=0.330423, expected=-0.064102
# predicted=-0.064102, expected=-0.097538
# predicted=-0.097538, expected=-0.060386
# predicted=-0.060386, expected=-0.094526
# predicted=-0.094526, expected=-0.091944
# predicted=-0.091944, expected=0.043559
# predicted=0.043559, expected=-0.087074
# predicted=-0.087074, expected=-0.085503
# predicted=-0.085503, expected=-0.021929
# predicted=-0.021929, expected=-0.013050
# predicted=-0.013050, expected=-0.077592
# predicted=-0.077592, expected=0.008466
# predicted=0.008466, expected=-0.096319
# predicted=-0.096319, expected=-0.080827
# predicted=-0.080827, expected=-0.090531
# predicted=-0.090531, expected=0.143374
# predicted=0.143374, expected=-0.076524
# predicted=-0.076524, expected=0.305392
# predicted=0.305392, expected=0.145827
# predicted=0.145827, expected=0.426150
# predicted=0.426150, expected=0.345850
# predicted=0.345850, expected=-0.086457
# predicted=-0.086457, expected=0.618097
# predicted=0.618097, expected=0.044269
# predicted=0.044269, expected=-0.096391
# predicted=-0.096391, expected=-0.006667
# predicted=-0.006667, expected=-0.095530
# predicted=-0.095530, expected=0.001287
# predicted=0.001287, expected=-0.045870
# predicted=-0.045870, expected=-0.085848
# predicted=-0.085848, expected=-0.070098
# predicted=-0.070098, expected=-0.082175
# predicted=-0.082175, expected=-0.066626
# predicted=-0.066626, expected=0.009198
# predicted=0.009198, expected=-0.040677
# predicted=-0.040677, expected=0.152669
# predicted=0.152669, expected=-0.085188
# predicted=-0.085188, expected=-0.091973
# predicted=-0.091973, expected=-0.090373
# predicted=-0.090373, expected=-0.063973
# predicted=-0.063973, expected=-0.046989
# predicted=-0.046989, expected=-0.095530
# predicted=-0.095530, expected=-0.060845
# predicted=-0.060845, expected=-0.061936
# predicted=-0.061936, expected=-0.067516
# predicted=-0.067516, expected=-0.050596
# predicted=-0.050596, expected=-0.061161
# predicted=-0.061161, expected=-0.097416
# predicted=-0.097416, expected=-0.075835
# predicted=-0.075835, expected=-0.046996
# predicted=-0.046996, expected=-0.076595
# predicted=-0.076595, expected=0.000024
# predicted=0.000024, expected=-0.090524
# predicted=-0.090524, expected=-0.057883
# predicted=-0.057883, expected=0.008466
# predicted=0.008466, expected=-0.041739
# predicted=-0.041739, expected=-0.062007
# predicted=-0.062007, expected=0.123184
# predicted=0.123184, expected=-0.048316
# predicted=-0.048316, expected=-0.056083
# predicted=-0.056083, expected=-0.063614
# predicted=-0.063614, expected=-0.067178
# predicted=-0.067178, expected=-0.045576
# predicted=-0.045576, expected=-0.087698
# predicted=-0.087698, expected=-0.089125
# predicted=-0.089125, expected=-0.066390
# predicted=-0.066390, expected=-0.070427
# predicted=-0.070427, expected=-0.088164
# predicted=-0.088164, expected=0.054726
# predicted=0.054726, expected=-0.094813
# predicted=-0.094813, expected=-0.041588
# predicted=-0.041588, expected=-0.039932
# predicted=-0.039932, expected=0.544224
# predicted=0.544224, expected=-0.091944
# predicted=-0.091944, expected=0.048056
# predicted=0.048056, expected=-0.055997
# predicted=-0.055997, expected=-0.086220
# predicted=-0.086220, expected=-0.054491
# predicted=-0.054491, expected=-0.071374
# predicted=-0.071374, expected=-0.090832
# predicted=-0.090832, expected=-0.064905
# predicted=-0.064905, expected=0.131970
# predicted=0.131970, expected=-0.068541
# predicted=-0.068541, expected=-0.052411
# predicted=-0.052411, expected=-0.040642
# predicted=-0.040642, expected=0.012690
# predicted=0.012690, expected=-0.092661
# predicted=-0.092661, expected=-0.066841
# predicted=-0.066841, expected=-0.022374
# predicted=-0.022374, expected=-0.044285
# predicted=-0.044285, expected=-0.065235
# predicted=-0.065235, expected=-0.063255
# predicted=-0.063255, expected=-0.079816
# predicted=-0.079816, expected=-0.084915
# predicted=-0.084915, expected=-0.044543
# predicted=-0.044543, expected=-0.091930
# predicted=-0.091930, expected=0.116048
# predicted=0.116048, expected=-0.055409
# predicted=-0.055409, expected=-0.097682
# predicted=-0.097682, expected=-0.050790
# predicted=-0.050790, expected=0.073015
# predicted=0.073015, expected=-0.032064
# predicted=-0.032064, expected=-0.076165
# predicted=-0.076165, expected=-0.561001
# predicted=-0.561001, expected=-0.073870
# predicted=-0.073870, expected=-0.017368
# predicted=-0.017368, expected=-0.072077
# predicted=-0.072077, expected=0.251709
# predicted=0.251709, expected=-0.094813
# predicted=-0.094813, expected=-0.065909
# predicted=-0.065909, expected=-0.065909
# predicted=-0.065909, expected=-0.095171
# predicted=-0.095171, expected=-0.092675
# predicted=-0.092675, expected=-0.036611
# predicted=-0.036611, expected=-0.063255
# predicted=-0.063255, expected=0.044327
# predicted=0.044327, expected=-0.059662
# predicted=-0.059662, expected=-0.052741
# predicted=-0.052741, expected=-0.073296
# predicted=-0.073296, expected=-0.063255
# predicted=-0.063255, expected=-0.088573
# predicted=-0.088573, expected=-0.077700
# predicted=-0.077700, expected=-0.077786
# predicted=-0.077786, expected=-0.042456
# predicted=-0.042456, expected=0.047196
# predicted=0.047196, expected=0.013149
# predicted=0.013149, expected=-0.038454
# predicted=-0.038454, expected=-0.049628
# predicted=-0.049628, expected=-0.052139
# predicted=-0.052139, expected=-0.092123
# predicted=-0.092123, expected=-0.095265
# predicted=-0.095265, expected=-0.065285
# predicted=-0.065285, expected=-0.044909
# predicted=-0.044909, expected=-0.084054
# predicted=-0.084054, expected=-0.061111
# predicted=-0.061111, expected=-0.084736
# predicted=-0.084736, expected=-0.091277
# predicted=-0.091277, expected=-0.049664
# predicted=-0.049664, expected=-0.096964
# predicted=-0.096964, expected=-0.096261
# predicted=-0.096261, expected=-0.090531
# predicted=-0.090531, expected=-0.106969
# predicted=-0.106969, expected=-0.090115
# predicted=-0.090115, expected=-0.078869
# predicted=-0.078869, expected=-0.089527
# predicted=-0.089527, expected=0.853508
# predicted=0.853508, expected=-0.075878
# predicted=-0.075878, expected=0.070821
# predicted=0.070821, expected=-0.050912
# predicted=-0.050912, expected=-0.057123
# predicted=-0.057123, expected=-0.090897
# predicted=-0.090897, expected=-0.033850
# predicted=-0.033850, expected=-0.041022
# predicted=-0.041022, expected=-0.096735
# predicted=-0.096735, expected=-0.094504
# predicted=-0.094504, expected=-0.073318
# predicted=-0.073318, expected=-0.091227
# predicted=-0.091227, expected=-0.055560
# predicted=-0.055560, expected=-0.083452
# predicted=-0.083452, expected=-0.094103
# predicted=-0.094103, expected=-0.087719
# predicted=-0.087719, expected=-0.043152
# predicted=-0.043152, expected=-0.091241
# predicted=-0.091241, expected=-0.035772
# predicted=-0.035772, expected=0.004880
# predicted=0.004880, expected=-0.090545
# predicted=-0.090545, expected=-0.083624
# predicted=-0.083624, expected=-0.051407
# predicted=-0.051407, expected=-0.063657
# predicted=-0.063657, expected=-0.044629
# predicted=-0.044629, expected=-0.084413
# predicted=-0.084413, expected=-0.081566
# predicted=-0.081566, expected=-0.077600
# predicted=-0.077600, expected=0.005239
# predicted=0.005239, expected=-0.064625
# predicted=-0.064625, expected=-0.095774
# predicted=-0.095774, expected=-0.087806
# predicted=-0.087806, expected=-0.050589
# predicted=-0.050589, expected=-0.065264
# predicted=-0.065264, expected=-0.062753
# predicted=-0.062753, expected=-0.075448
# predicted=-0.075448, expected=-0.045612
# predicted=-0.045612, expected=-0.055402
# predicted=-0.055402, expected=-0.093213
# predicted=-0.093213, expected=-0.097108
# predicted=-0.097108, expected=-0.084772
# predicted=-0.084772, expected=-0.081193
# predicted=-0.081193, expected=-0.127747
# predicted=-0.127747, expected=-0.094282
# predicted=-0.094282, expected=-0.091829
# predicted=-0.091829, expected=-0.037099
# predicted=-0.037099, expected=-0.056083
# predicted=-0.056083, expected=-0.090904
# predicted=-0.090904, expected=-0.089799
# predicted=-0.089799, expected=-0.001582
# predicted=-0.001582, expected=-0.048007
# predicted=-0.048007, expected=0.048773
# predicted=0.048773, expected=-0.076918
# predicted=-0.076918, expected=-0.094676
# predicted=-0.094676, expected=-0.087655
# predicted=-0.087655, expected=-0.095530
# predicted=-0.095530, expected=-0.077607
# predicted=-0.077607, expected=-0.063298
# predicted=-0.063298, expected=-0.092654
# predicted=-0.092654, expected=-0.065106
# predicted=-0.065106, expected=-0.094397
# predicted=-0.094397, expected=-0.075003
# predicted=-0.075003, expected=-0.085130
# predicted=-0.085130, expected=-0.078317
# predicted=-0.078317, expected=-0.074415
# predicted=-0.074415, expected=-0.101160
# predicted=-0.101160, expected=-0.094526
# predicted=-0.094526, expected=-0.096247
# predicted=-0.096247, expected=-0.082591
# predicted=-0.082591, expected=-0.068885
# predicted=-0.068885, expected=-0.084707
# predicted=-0.084707, expected=-0.090509
# predicted=-0.090509, expected=0.180576
# predicted=0.180576, expected=-0.077607
# predicted=-0.077607, expected=-0.074014
# predicted=-0.074014, expected=-0.059669
# predicted=-0.059669, expected=-0.065708
# predicted=-0.065708, expected=0.010288
# predicted=0.010288, expected=-0.071754
# predicted=-0.071754, expected=-0.097682
# predicted=-0.097682, expected=-0.056951
# predicted=-0.056951, expected=-0.142794
# predicted=-0.142794, expected=-0.117039
# predicted=-0.117039, expected=-0.048839
# predicted=-0.048839, expected=-0.059282
# predicted=-0.059282, expected=-0.062538
# predicted=-0.062538, expected=-0.088358
# predicted=-0.088358, expected=-0.088358
# predicted=-0.088358, expected=-0.071718
# predicted=-0.071718, expected=-0.050553
# predicted=-0.050553, expected=-0.102695
# predicted=-0.102695, expected=-0.046092
# predicted=-0.046092, expected=0.187755
# predicted=0.187755, expected=-0.042384
# predicted=-0.042384, expected=0.109643
# predicted=0.109643, expected=0.118974
# predicted=0.118974, expected=-0.056808
# predicted=-0.056808, expected=-0.078568
# predicted=-0.078568, expected=-0.058672
# predicted=-0.058672, expected=-0.079220
# predicted=-0.079220, expected=-0.060838
# predicted=-0.060838, expected=-0.041151
# predicted=-0.041151, expected=-0.069366
# predicted=-0.069366, expected=-0.085130
# predicted=-0.085130, expected=-0.069933
# predicted=-0.069933, expected=-0.065866
# predicted=-0.065866, expected=-0.083603
# predicted=-0.083603, expected=-0.060157
# predicted=-0.060157, expected=-0.055151
# predicted=-0.055151, expected=-0.034545
# predicted=-0.034545, expected=-0.942559
# predicted=-0.942559, expected=-0.077600
# predicted=-0.077600, expected=-0.088358
# predicted=-0.088358, expected=-0.092302
# predicted=-0.092302, expected=-0.091944
# predicted=-0.091944, expected=-0.003476
# predicted=-0.003476, expected=-0.052526
# predicted=-0.052526, expected=-0.016952
# predicted=-0.016952, expected=-0.087526
# predicted=-0.087526, expected=-0.025659
# predicted=-0.025659, expected=-0.117039
# predicted=-0.117039, expected=-0.045153
# predicted=-0.045153, expected=-0.086565
# predicted=-0.086565, expected=-0.053214
# predicted=-0.053214, expected=-0.079723
# predicted=-0.079723, expected=-0.097330
# predicted=-0.097330, expected=-0.094490
# predicted=-0.094490, expected=-0.015460
# predicted=-0.015460, expected=0.019762
# predicted=0.019762, expected=-0.117032
# predicted=-0.117032, expected=-0.090531
# predicted=-0.090531, expected=-0.082792
# predicted=-0.082792, expected=0.065485
# predicted=0.065485, expected=-0.090509
# predicted=-0.090509, expected=-0.009070
# predicted=-0.009070, expected=-0.094095
# predicted=-0.094095, expected=-0.063958
# predicted=-0.063958, expected=-0.090954
# predicted=-0.090954, expected=-0.095530
# predicted=-0.095530, expected=-0.074021
# predicted=-0.074021, expected=-0.090832
# predicted=-0.090832, expected=-0.083337
# predicted=-0.083337, expected=-0.084076
# predicted=-0.084076, expected=-0.094777
# predicted=-0.094777, expected=0.097680
# predicted=0.097680, expected=-0.058529
# predicted=-0.058529, expected=-0.062753
# predicted=-0.062753, expected=-0.044758
# predicted=-0.044758, expected=-0.069352
# predicted=-0.069352, expected=-0.006222
# predicted=-0.006222, expected=-0.037436
# predicted=-0.037436, expected=-0.089792
# predicted=-0.089792, expected=-0.070248
# predicted=-0.070248, expected=-0.067150
# predicted=-0.067150, expected=-0.039021
# predicted=-0.039021, expected=-0.052375
# predicted=-0.052375, expected=-0.175851
# predicted=-0.175851, expected=0.132494
# predicted=0.132494, expected=-0.085891
# predicted=-0.085891, expected=-0.080504
# predicted=-0.080504, expected=-0.080124
# predicted=-0.080124, expected=-0.092747
# predicted=-0.092747, expected=-0.059669
# predicted=-0.059669, expected=-0.046759
# predicted=-0.046759, expected=0.461064
# predicted=0.461064, expected=-0.093091
# predicted=-0.093091, expected=-0.093708
# predicted=-0.093708, expected=-0.149321
# predicted=-0.149321, expected=1.884374
# predicted=1.884374, expected=-0.096254
# predicted=-0.096254, expected=-0.042456
# predicted=-0.042456, expected=-0.094820
# predicted=-0.094820, expected=-0.098549
# predicted=-0.098549, expected=1.389389
# predicted=1.389389, expected=-0.096326
# predicted=-0.096326, expected=-0.088351
# predicted=-0.088351, expected=-0.093020
# predicted=-0.093020, expected=-0.097000
# predicted=-0.097000, expected=-0.070392
# predicted=-0.070392, expected=0.126240
# predicted=0.126240, expected=-0.095745
# predicted=-0.095745, expected=-0.097323
# predicted=-0.097323, expected=-0.086507
# predicted=-0.086507, expected=-0.090517
# predicted=-0.090517, expected=-0.089986
# predicted=-0.089986, expected=-0.077600
# predicted=-0.077600, expected=-0.066841
# predicted=-0.066841, expected=0.093814
# predicted=0.093814, expected=-0.039867
# predicted=-0.039867, expected=-0.086206
# predicted=-0.086206, expected=-0.092317
# predicted=-0.092317, expected=-0.068599
# predicted=-0.068599, expected=-0.038182
# predicted=-0.038182, expected=-0.058393
# predicted=-0.058393, expected=-0.089799
# predicted=-0.089799, expected=-0.059970
# predicted=-0.059970, expected=-0.048947
# predicted=-0.048947, expected=-0.079486
# predicted=-0.079486, expected=-0.072407
# predicted=-0.072407, expected=-0.084284
# predicted=-0.084284, expected=-0.088358
# predicted=-0.088358, expected=-0.086887
# predicted=-0.086887, expected=-0.058909
# predicted=-0.058909, expected=-0.096039
# predicted=-0.096039, expected=-0.087712
# predicted=-0.087712, expected=-0.088358
# predicted=-0.088358, expected=-0.091944
# predicted=-0.091944, expected=-0.070427
# predicted=-0.070427, expected=-0.080038
# predicted=-0.080038, expected=-0.022023
# predicted=-0.022023, expected=-0.091155
# predicted=-0.091155, expected=-0.081186
# predicted=-0.081186, expected=-0.089799
# predicted=-0.089799, expected=-0.082642
# predicted=-0.082642, expected=-0.088358
# predicted=-0.088358, expected=-0.065378
# predicted=-0.065378, expected=-0.047993
# predicted=-0.047993, expected=-0.083509
# predicted=-0.083509, expected=-0.094978
# predicted=-0.094978, expected=-0.038153
# predicted=-0.038153, expected=-0.049987
# predicted=-0.049987, expected=-0.083294
# predicted=-0.083294, expected=-0.070607
# predicted=-0.070607, expected=-0.088724
# predicted=-0.088724, expected=-0.082864
# predicted=-0.082864, expected=0.044327
# predicted=0.044327, expected=-0.091944
# predicted=-0.091944, expected=-0.057439
# predicted=-0.057439, expected=-0.063973
# predicted=-0.063973, expected=0.042899
# predicted=0.042899, expected=-0.093385
# predicted=-0.093385, expected=-0.081630
# predicted=-0.081630, expected=-0.095989
# predicted=-0.095989, expected=-0.086206
# predicted=-0.086206, expected=-0.087755
# predicted=-0.087755, expected=-0.085898
# predicted=-0.085898, expected=-0.078969
# predicted=-0.078969, expected=-0.089799
# predicted=-0.089799, expected=-0.104847
# Test MSE: 0.040

# %%
# Forecasting using the ARIMA model

autocorrelation_plot(train_set[0:20])
plt.figure(figsize=(25,20))
plt.show()

# %%
arima_model = ARIMA(train_set, order=(2,0,7))
arima_model_fit = arima_model.fit()

# %%
print(arima_model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:     ORIGINAL GROSS AMT   No. Observations:                30613
# Model:                 ARIMA(2, 0, 7)   Log Likelihood               15729.668
# Date:                Sun, 31 Jan 2021   AIC                         -31437.337
# Time:                        15:41:23   BIC                         -31345.716
# Sample:                    06-25-2015   HQIC                        -31407.967
#                          - 08-15-2016
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0356      0.002    -19.225      0.000      -0.039      -0.032
# ar.L1          0.3135      0.417      0.752      0.452      -0.504       1.131
# ar.L2          0.5510      0.375      1.468      0.142      -0.185       1.287
# ma.L1         -0.2294      0.417     -0.550      0.582      -1.047       0.588
# ma.L2         -0.5316      0.340     -1.563      0.118      -1.198       0.135
# ma.L3         -0.0433      0.014     -3.099      0.002      -0.071      -0.016
# ma.L4          0.0058      0.011      0.528      0.598      -0.016       0.027
# ma.L5          0.0321      0.009      3.406      0.001       0.014       0.051
# ma.L6         -0.0039      0.009     -0.456      0.649      -0.021       0.013
# ma.L7         -0.0188      0.007     -2.532      0.011      -0.033      -0.004
# sigma2         0.0210   3.73e-05    561.129      0.000       0.021       0.021
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):          11722986.45
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.30   Skew:                             6.98
# Prob(H) (two-sided):                  0.00   Kurtosis:                        97.85
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
residuals = pd.DataFrame(arima_model_fit.resid)
residuals.plot()
plt.show()
# density plot of residuals
residuals.plot(kind='kde')
plt.show()
# summary stats of residuals
print(residuals.describe())
# Out:
#                   0
# count  30613.000000
# mean       0.000011
# std        0.144750
# min       -1.018359
# 25%       -0.050644
# 50%       -0.033940
# 75%       -0.000620
# max        3.196120

# %%
history = [x for x in train_set]
predictions = list()
# walk-forward validation
for t in range(len(test_set)):
    model = ARIMA(history, order=(0,1,5))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test_set[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
# evaluate forecasts
rmse = sqrt(mean_squared_error(test_set, predictions))
print('Test RMSE: %.3f' % rmse)
# plot forecasts against actual outcomes
plt.plot(test_set)
plt.plot(predictions, color='red')
plt.show()
# Out:
# predicted=0.051129, expected=2.009492
# predicted=0.168087, expected=-0.042349
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-147-4e8da585b41b> in <module>
#       4 for t in range(len(test_set)):
#       5     model = ARIMA(history, order=(0,1,5))
# ----> 6     model_fit = model.fit()
#       7     output = model_fit.forecast()
#       8     yhat = output[0]
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima\model.py in fit(self, start_params, transformed, includes_fixed, method, method_kwargs, gls, gls_kwargs, cov_type, cov_kwds, return_params, low_memory)
#     340                 method_kwargs.setdefault('disp', 0)
#     341
# --> 342                 res = super(ARIMA, self).fit(
#     343                     return_params=return_params, low_memory=low_memory,
#     344                     cov_type=cov_type, cov_kwds=cov_kwds, **method_kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     688                 flags['hessian_method'] = optim_hessian
#     689             fargs = (flags,)
# --> 690             mlefit = super(MLEModel, self).fit(start_params, method=method,
#     691                                                fargs=fargs,
#     692                                                maxiter=maxiter,
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     517         warn_convergence = kwargs.pop('warn_convergence', True)
#     518         optimizer = Optimizer()
# --> 519         xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     520                                                        fargs, kwargs,
#     521                                                        hessian=hess,
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     213
#     214         func = fit_funcs[method]
# --> 215         xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     216                             disp=disp, maxiter=maxiter, callback=callback,
#     217                             retall=retall, full_output=full_output,
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     450         func = f
#     451
# --> 452     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#     453                                      callback=callback, args=fargs,
#     454                                      bounds=bounds, disp=disp,
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     195             'maxls': maxls}
#     196
# --> 197     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     198                            **opts)
#     199     d = {'grad': res['jac'],
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_and_grad(self, x)
#     199             self._update_x_impl(x)
#     200         self._update_fun()
# --> 201         self._update_grad()
#     202         return self.f, self.g
#     203
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in _update_grad(self)
#     169     def _update_grad(self):
#     170         if not self.g_updated:
# --> 171             self._update_grad_impl()
#     172             self.g_updated = True
#     173
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in update_grad()
#      89                 self._update_fun()
#      90                 self.ngev += 1
# ---> 91                 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#      92                                            **finite_diff_options)
#      93
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\_numdiff.py in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     424
#     425         if sparsity is None:
# --> 426             return _dense_difference(fun_wrapped, x0, f0, h,
#     427                                      use_one_sided, method)
#     428         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\_numdiff.py in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     495             x = x0 + h_vecs[i]
#     496             dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 497             df = fun(x) - f0
#     498         elif method == '3-point' and use_one_sided[i]:
#     499             x1 = x0 + h_vecs[i]
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\_numdiff.py in fun_wrapped(x)
#     375
#     376     def fun_wrapped(x):
# --> 377         f = np.atleast_1d(fun(x, *args, **kwargs))
#     378         if f.ndim > 1:
#     379             raise RuntimeError("`fun` return value has "
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_wrapped(x)
#      68         def fun_wrapped(x):
#      69             self.nfev += 1
# ---> 70             return fun(x, *args)
#      71
#      72         def update_fun():
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py in f(params, *args)
#     499
#     500         def f(params, *args):
# --> 501             return -self.loglike(params, *args) / nobs
#     502
#     503         if method == 'newton':
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in loglike(self, params, *args, **kwargs)
#     923             kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
#     924
# --> 925         loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#     926
#     927         # Koopman, Shephard, and Doornik recommend maximizing the average
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py in loglike(self, **kwargs)
#     981         kwargs.setdefault('conserve_memory',
#     982                           MEMORY_CONSERVE ^ MEMORY_NO_LIKELIHOOD)
# --> 983         kfilter = self._filter(**kwargs)
#     984         loglikelihood_burn = kwargs.get('loglikelihood_burn',
#     985                                         self.loglikelihood_burn)
#
# KeyboardInterrupt:
